# %%
import pickle
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import sys; sys.path.append("../../..")  # Allows access to all the scripts/modules in the larger directory
from utils import calc_loadings
from sklearn.metrics import hamming_loss, accuracy_score
from collections import defaultdict
from scipy.linalg import subspace_angles

# %% [markdown]
# ### Load consolidated decoding dataframe

# %%
decoding_glom_path = '/home/marcush/Data/TsaoLabData/neural_control_output/decoding_clear_final_analysis_230322_214006_Jamie/decoding_clear_final_analysis_230322_214006_Jamie_glom.pickle'
with open(decoding_glom_path, 'rb') as f:
    dat_decode = pickle.load(f) 

df_decode = pd.DataFrame(dat_decode)

# %%
# Helpful ways to index / look at the df_decode
filtered_df_decode = df_decode[(df_decode['loader_args'].apply(lambda x: x.get('region')) == 'AM') & (df_decode['dimreduc_method'] == 'PCA') ]
df_decode.columns
# Out:
# Index(['dim', 'fold_idx', 'train_idxs', 'test_idxs', 'dimreduc_method',
#        'dimreduc_args', 'coef', 'score', 'full_arg_tuple', 'predictions',
#        'loss', 'decoding_object', 'Xtrain', 'Xtest', 'Ytrain', 'Ytest',
#        'decoder', 'decoder_args', 'thresholds', 'data_file', 'loader',
#        'loader_args', 'task_args', 'data_path', 'results_file'],
#       dtype='object')

# %%
data_path = df_decode['data_path']

# %% [markdown]
# #### Load the processed data as well for other info

# %%
def make_hashable(obj):
    if isinstance(obj, dict):
        return tuple(sorted((key, make_hashable(value)) for key, value in obj.items()))
    elif isinstance(obj, (list, tuple)):
        return tuple(make_hashable(item) for item in obj)
    else:
        return obj


unique_hashes = set(make_hashable(d) for d in df_decode['full_arg_tuple'])
unique_dicts = [dict(u) for u in unique_hashes]

# %%
preload_dict_path = df_decode['data_path'][0] + "/preloaded/preloadDict.pickle"

with open(preload_dict_path, 'rb') as file:
    preloadDict = pickle.load(file)


for arg_dict in unique_dicts:
    arg_tuple = tuple(sorted(arg_dict.items()))


    for args in preloadDict.keys():

        if args == arg_tuple:

            preloadID = preloadDict[arg_tuple]
            loaded_data_path = os.path.dirname(preload_dict_path) + f"/preloaded_data_{preloadID}.pickle"
            
            if arg_dict['region'] == 'AM':
                with open(loaded_data_path, 'rb') as file:
                    AM_loaded_data = pickle.load(file)

            elif arg_dict['region'] == 'ML':
                with open(loaded_data_path, 'rb') as file:
                    ML_loaded_data = pickle.load(file)

AM_spikes = np.sum(AM_loaded_data['spike_rates'], 1)
ML_spikes = np.sum(ML_loaded_data['spike_rates'], 1)

# %%
AM_spikes.shape, ML_spikes.shape
# Out:
# ((3001, 270), (3001, 413))

# %%
AM_loaded_data["StimulusNames"]
# Out:
# ['clear_train_00002.png',
#  'clear_train_00012.png',
#  'clear_train_00019.png',
#  'clear_train_00042.png',
#  'clear_train_00048.png',
#  'clear_train_00050.png',
#  'clear_train_00051.png',
#  'clear_train_00055.png',
#  'clear_train_00057.png',
#  'clear_train_00059.png',
#  'clear_train_00061.png',
#  'clear_train_00067.png',
#  'clear_train_00071.png',
#  'clear_train_00075.png',
#  'clear_train_00085.png',
#  'clear_train_00092.png',
#  'clear_train_00094.png',
#  'clear_train_00096.png',
#  'clear_train_00100.png',
#  'clear_train_00101.png',
#  'clear_train_00107.png',
#  'clear_train_00110.png',
#  'clear_train_00118.png',
#  'clear_train_00120.png',
#  'clear_train_00121.png',
#  'clear_train_00123.png',
#  'clear_train_00124.png',
#  'clear_train_00125.png',
#  'clear_train_00126.png',
#  'clear_train_00129.png',
#  'clear_train_00131.png',
#  'clear_train_00132.png',
#  'clear_train_00135.png',
#  'clear_train_00138.png',
#  'clear_train_00143.png',
#  'clear_train_00144.png',
#  'clear_train_00148.png',
#  'clear_train_00152.png',
#  'clear_train_00165.png',
#  'clear_train_00177.png',
#  'clear_train_00178.png',
#  'clear_train_00182.png',
#  'clear_train_00183.png',
#  'clear_train_00189.png',
#  'clear_train_00195.png',
#  'clear_train_00196.png',
#  'clear_train_00198.png',
#  'clear_train_00207.png',
#  'clear_train_00210.png',
#  'clear_train_00215.png',
#  'clear_train_00217.png',
#  'clear_train_00221.png',
#  'clear_train_00223.png',
#  'clear_train_00234.png',
#  'clear_train_00239.png',
#  'clear_train_00243.png',
#  'clear_train_00244.png',
#  'clear_train_00249.png',
#  'clear_train_00257.png',
#  'clear_train_00258.png',
#  'clear_train_00260.png',
#  'clear_train_00267.png',
#  'clear_train_00268.png',
#  'clear_train_00278.png',
#  'clear_train_00282.png',
#  'clear_train_00290.png',
#  'clear_train_00293.png',
#  'clear_train_00298.png',
#  'clear_train_00305.png',
#  'clear_train_00306.png',
#  'clear_train_00307.png',
#  'clear_train_00309.png',
#  'clear_train_00310.png',
#  'clear_train_00311.png',
#  'clear_train_00316.png',
#  'clear_train_00317.png',
#  'clear_train_00325.png',
#  'clear_train_00326.png',
#  'clear_train_00336.png',
#  'clear_train_00342.png',
#  'clear_train_00343.png',
#  'clear_train_00346.png',
#  'clear_train_00347.png',
#  'clear_train_00348.png',
#  'clear_train_00351.png',
#  'clear_train_00358.png',
#  'clear_train_00366.png',
#  'clear_train_00372.png',
#  'clear_train_00377.png',
#  'clear_train_00386.png',
#  'clear_train_00388.png',
#  'clear_train_00391.png',
#  'clear_train_00393.png',
#  'clear_train_00397.png',
#  'clear_train_00409.png',
#  'clear_train_00410.png',
#  'clear_train_00415.png',
#  'clear_train_00416.png',
#  'clear_train_00428.png',
#  'clear_train_00430.png',
#  'clear_train_00447.png',
#  'clear_train_00451.png',
#  'clear_train_00452.png',
#  'clear_train_00457.png',
#  'clear_train_00459.png',
#  'clear_train_00469.png',
#  'clear_train_00474.png',
#  'clear_train_00479.png',
#  'clear_train_00480.png',
#  'clear_train_00481.png',
#  'clear_train_00484.png',
#  'clear_train_00505.png',
#  'clear_train_00519.png',
#  'clear_train_00529.png',
#  'clear_train_00541.png',
#  'clear_train_00544.png',
#  'clear_train_00549.png',
#  'clear_train_00554.png',
#  'clear_train_00558.png',
#  'clear_train_00559.png',
#  'clear_train_00563.png',
#  'clear_train_00567.png',
#  'clear_train_00573.png',
#  'clear_train_00582.png',
#  'clear_train_00585.png',
#  'clear_train_00587.png',
#  'clear_train_00588.png',
#  'clear_train_00590.png',
#  'clear_train_00592.png',
#  'clear_train_00594.png',
#  'clear_train_00597.png',
#  'clear_train_00600.png',
#  'clear_train_00601.png',
#  'clear_train_00606.png',
#  'clear_train_00607.png',
#  'clear_train_00615.png',
#  'clear_train_00619.png',
#  'clear_train_00620.png',
#  'clear_train_00621.png',
#  'clear_train_00623.png',
#  'clear_train_00624.png',
#  'clear_train_00627.png',
#  'clear_train_00633.png',
#  'clear_train_00634.png',
#  'clear_train_00635.png',
#  'clear_train_00636.png',
#  'clear_train_00639.png',
#  'clear_train_00643.png',
#  'clear_train_00644.png',
#  'clear_train_00645.png',
#  'clear_train_00647.png',
#  'clear_train_00650.png',
#  'clear_train_00653.png',
#  'clear_train_00655.png',
#  'clear_train_00658.png',
#  'clear_train_00660.png',
#  'clear_train_00661.png',
#  'clear_train_00662.png',
#  'clear_train_00663.png',
#  'clear_train_00668.png',
#  'clear_train_00670.png',
#  'clear_train_00671.png',
#  'clear_train_00674.png',
#  'clear_train_00675.png',
#  'clear_train_00688.png',
#  'clear_train_00694.png',
#  'clear_train_00700.png',
#  'clear_train_00701.png',
#  'clear_train_00704.png',
#  'clear_train_00706.png',
#  'clear_train_00711.png',
#  'clear_train_00712.png',
#  'clear_train_00721.png',
#  'clear_train_00722.png',
#  'clear_train_00723.png',
#  'clear_train_00724.png',
#  'clear_train_00726.png',
#  'clear_train_00727.png',
#  'clear_train_00737.png',
#  'clear_train_00738.png',
#  'clear_train_00742.png',
#  'clear_train_00743.png',
#  'clear_train_00745.png',
#  'clear_train_00747.png',
#  'clear_train_00750.png',
#  'clear_train_00752.png',
#  'clear_train_00753.png',
#  'clear_train_00756.png',
#  'clear_train_00757.png',
#  'clear_train_00760.png',
#  'clear_train_00763.png',
#  'clear_train_00767.png',
#  'clear_train_00771.png',
#  'clear_train_00775.png',
#  'clear_train_00776.png',
#  'clear_train_00777.png',
#  'clear_train_00778.png',
#  'clear_train_00779.png',
#  'clear_train_00784.png',
#  'clear_train_00788.png',
#  'clear_train_00792.png',
#  'clear_train_00793.png',
#  'clear_train_00796.png',
#  'clear_train_00798.png',
#  'clear_train_00799.png',
#  'clear_train_00802.png',
#  'clear_train_00807.png',
#  'clear_train_00810.png',
#  'clear_train_00817.png',
#  'clear_train_00820.png',
#  'clear_train_00821.png',
#  'clear_train_00822.png',
#  'clear_train_00824.png',
#  'clear_train_00829.png',
#  'clear_train_00834.png',
#  'clear_train_00839.png',
#  'clear_train_00841.png',
#  'clear_train_00852.png',
#  'clear_train_00853.png',
#  'clear_train_00856.png',
#  'clear_train_00863.png',
#  'clear_train_00864.png',
#  'clear_train_00867.png',
#  'clear_train_00868.png',
#  'clear_train_00870.png',
#  'clear_train_00871.png',
#  'clear_train_00874.png',
#  'clear_train_00878.png',
#  'clear_train_00884.png',
#  'clear_train_00886.png',
#  'clear_train_00887.png',
#  'clear_train_00890.png',
#  'clear_train_00892.png',
#  'clear_train_00896.png',
#  'clear_train_00899.png',
#  'clear_train_00904.png',
#  'clear_train_00906.png',
#  'clear_train_00907.png',
#  'clear_train_00909.png',
#  'clear_train_00910.png',
#  'clear_train_00913.png',
#  'clear_train_00914.png',
#  'clear_train_00915.png',
#  'clear_train_00927.png',
#  'clear_train_00928.png',
#  'clear_train_00932.png',
#  'clear_train_00933.png',
#  'clear_train_00935.png',
#  'clear_train_00937.png',
#  'clear_train_00941.png',
#  'clear_train_00946.png',
#  'clear_train_00948.png',
#  'clear_train_00949.png',
#  'clear_train_00950.png',
#  'clear_train_00952.png',
#  'clear_train_00953.png',
#  'clear_train_00956.png',
#  'clear_train_00996.png',
#  'clear_train_00998.png',
#  'clear_train_01001.png',
#  'clear_train_01003.png',
#  'clear_train_01004.png',
#  'clear_train_01006.png',
#  'clear_train_01017.png',
#  'clear_train_01020.png',
#  'clear_train_01021.png',
#  'clear_train_01022.png',
#  'clear_train_01024.png',
#  'clear_train_01025.png',
#  'clear_train_01026.png',
#  'clear_train_01027.png',
#  'clear_train_01029.png',
#  'clear_train_01034.png',
#  'clear_train_01035.png',
#  'clear_train_01038.png',
#  'clear_train_01039.png',
#  'clear_train_01040.png',
#  'clear_train_01041.png',
#  'clear_train_01044.png',
#  'clear_train_01045.png',
#  'clear_train_01046.png',
#  'clear_train_01048.png',
#  'clear_train_01051.png',
#  'clear_train_01054.png',
#  'clear_train_01055.png',
#  'clear_train_01065.png',
#  'clear_train_01069.png',
#  'clear_train_01072.png',
#  'clear_train_01074.png',
#  'clear_train_01076.png',
#  'clear_train_01080.png',
#  'clear_train_01082.png',
#  'clear_train_01084.png',
#  'clear_train_01088.png',
#  'clear_train_01089.png',
#  'clear_train_01091.png',
#  'clear_train_01092.png',
#  'clear_train_01093.png',
#  'clear_train_01094.png',
#  'clear_train_01095.png',
#  'clear_train_01099.png',
#  'clear_train_01100.png',
#  'clear_train_01101.png',
#  'clear_train_01105.png',
#  'clear_train_01108.png',
#  'clear_train_01111.png',
#  'clear_train_01115.png',
#  'clear_train_01117.png',
#  'clear_train_01118.png',
#  'clear_train_01119.png',
#  'clear_train_01120.png',
#  'clear_train_01121.png',
#  'clear_train_01124.png',
#  'clear_train_01128.png',
#  'clear_train_01136.png',
#  'clear_train_01142.png',
#  'clear_train_01144.png',
#  'clear_train_01148.png',
#  'clear_train_01149.png',
#  'clear_train_01150.png',
#  'clear_train_01152.png',
#  'clear_train_01155.png',
#  'clear_train_01157.png',
#  'clear_train_01158.png',
#  'clear_train_01159.png',
#  'clear_train_01161.png',
#  'clear_train_01162.png',
#  'clear_train_01164.png',
#  'clear_train_01165.png',
#  'clear_train_01166.png',
#  'clear_train_01169.png',
#  'clear_train_01172.png',
#  'clear_train_01175.png',
#  'clear_train_01179.png',
#  'clear_train_01185.png',
#  'clear_train_01187.png',
#  'clear_train_01190.png',
#  'clear_train_01193.png',
#  'clear_train_01198.png',
#  'clear_train_01203.png',
#  'clear_train_01204.png',
#  'clear_train_01211.png',
#  'clear_train_01219.png',
#  'clear_train_01224.png',
#  'clear_train_01237.png',
#  'clear_train_01243.png',
#  'clear_train_01246.png',
#  'clear_train_01247.png',
#  'clear_train_01249.png',
#  'clear_train_01254.png',
#  'clear_train_01255.png',
#  'clear_train_01256.png',
#  'clear_train_01259.png',
#  'clear_train_01260.png',
#  'clear_train_01262.png',
#  'clear_train_01264.png',
#  'clear_train_01265.png',
#  'clear_train_01267.png',
#  'clear_train_01268.png',
#  'clear_train_01269.png',
#  'clear_train_01274.png',
#  'clear_train_01276.png',
#  'clear_train_01279.png',
#  'clear_train_01281.png',
#  'clear_train_01285.png',
#  'clear_train_01286.png',
#  'clear_train_01292.png',
#  'clear_train_01295.png',
#  'clear_train_01298.png',
#  'clear_train_01304.png',
#  'clear_train_01310.png',
#  'clear_train_01313.png',
#  'clear_train_01314.png',
#  'clear_train_01316.png',
#  'clear_train_01319.png',
#  'clear_train_01320.png',
#  'clear_train_01322.png',
#  'clear_train_01323.png',
#  'clear_train_01326.png',
#  'clear_train_01328.png',
#  'clear_train_01330.png',
#  'clear_train_01331.png',
#  'clear_train_01332.png',
#  'clear_train_01334.png',
#  'clear_train_01335.png',
#  'clear_train_01336.png',
#  'clear_train_01337.png',
#  'clear_train_01343.png',
#  'clear_train_01348.png',
#  'clear_train_01350.png',
#  'clear_train_01351.png',
#  'clear_train_01352.png',
#  'clear_train_01353.png',
#  'clear_train_01354.png',
#  'clear_train_01355.png',
#  'clear_train_01357.png',
#  'clear_train_01361.png',
#  'clear_train_01365.png',
#  'clear_train_01368.png',
#  'clear_train_01369.png',
#  'clear_train_01370.png',
#  'clear_train_01372.png',
#  'clear_train_01374.png',
#  'clear_train_01376.png',
#  'clear_train_01380.png',
#  'clear_train_01384.png',
#  'clear_train_01386.png',
#  'clear_train_01389.png',
#  'clear_train_01391.png',
#  'clear_train_01392.png',
#  'clear_train_01397.png',
#  'clear_train_01402.png',
#  'clear_train_01403.png',
#  'clear_train_01404.png',
#  'clear_train_01409.png',
#  'clear_train_01413.png',
#  'clear_train_01415.png',
#  'clear_train_01416.png',
#  'clear_train_01417.png',
#  'clear_train_01419.png',
#  'clear_train_01425.png',
#  'clear_train_01426.png',
#  'clear_train_01427.png',
#  'clear_train_01429.png',
#  'clear_train_01430.png',
#  'clear_train_01431.png',
#  'clear_train_01432.png',
#  'clear_train_01433.png',
#  'clear_train_01435.png',
#  'clear_train_01436.png',
#  'clear_train_01440.png',
#  'clear_train_01443.png',
#  'clear_train_01444.png',
#  'clear_train_01445.png',
#  'clear_train_01451.png',
#  'clear_train_01455.png',
#  'clear_train_01460.png',
#  'clear_train_01464.png',
#  'clear_train_01465.png',
#  'clear_train_01474.png',
#  'clear_train_01476.png',
#  'clear_train_01477.png',
#  'clear_train_01478.png',
#  'clear_train_01479.png',
#  'clear_train_01483.png',
#  'clear_train_01484.png',
#  'clear_train_01485.png',
#  'clear_train_01488.png',
#  'clear_train_01489.png',
#  'clear_train_01491.png',
#  'clear_train_01493.png',
#  'clear_train_01495.png',
#  'clear_train_01500.png',
#  'clear_train_01503.png',
#  'clear_train_01504.png',
#  'clear_train_01505.png',
#  'clear_train_01506.png',
#  'clear_train_01508.png',
#  'clear_train_01512.png',
#  'clear_train_01514.png',
#  'clear_train_01517.png',
#  'clear_train_01520.png',
#  'clear_train_01522.png',
#  'clear_train_01523.png',
#  'clear_train_01525.png',
#  'clear_train_01528.png',
#  'clear_train_01534.png',
#  'clear_train_01539.png',
#  'clear_train_01542.png',
#  'clear_train_01543.png',
#  'clear_train_01544.png',
#  'clear_train_01546.png',
#  'clear_train_01549.png',
#  'clear_train_01552.png',
#  'clear_train_01553.png',
#  'clear_train_01554.png',
#  'clear_train_01556.png',
#  'clear_train_01558.png',
#  'clear_train_01559.png',
#  'clear_train_01560.png',
#  'clear_train_01562.png',
#  'clear_train_01567.png',
#  'clear_train_01569.png',
#  'clear_train_01570.png',
#  'clear_train_01572.png',
#  'clear_train_01574.png',
#  'clear_train_01576.png',
#  'clear_train_01577.png',
#  'clear_train_01578.png',
#  'clear_train_01579.png',
#  'clear_train_01580.png',
#  'clear_train_01582.png',
#  'clear_train_01584.png',
#  'clear_train_01585.png',
#  'clear_train_01587.png',
#  'clear_train_01590.png',
#  'clear_train_02632.png',
#  'clear_train_02643.png',
#  'clear_train_02644.png',
#  'clear_train_02645.png',
#  'clear_train_02646.png',
#  'clear_train_02648.png',
#  'clear_train_02651.png',
#  'clear_train_02653.png',
#  'clear_train_02654.png',
#  'clear_train_02655.png',
#  'clear_train_02657.png',
#  'clear_train_02659.png',
#  'clear_train_02660.png',
#  'clear_train_02662.png',
#  'clear_train_02663.png',
#  'clear_train_02667.png',
#  'clear_train_02672.png',
#  'clear_train_02674.png',
#  'clear_train_02677.png',
#  'clear_train_02679.png',
#  'clear_train_02681.png',
#  'clear_train_02686.png',
#  'clear_train_02688.png',
#  'clear_train_02689.png',
#  'clear_train_02694.png',
#  'clear_train_02695.png',
#  'clear_train_02698.png',
#  'clear_train_02704.png',
#  'clear_train_02705.png',
#  'clear_train_02706.png',
#  'clear_train_02707.png',
#  'clear_train_02708.png',
#  'clear_train_02748.png',
#  'clear_train_02751.png',
#  'clear_train_02753.png',
#  'clear_train_02754.png',
#  'clear_train_02761.png',
#  'clear_train_02762.png',
#  'clear_train_02765.png',
#  'clear_train_02768.png',
#  'clear_train_02771.png',
#  'clear_train_02776.png',
#  'clear_train_02778.png',
#  'clear_train_02785.png',
#  'clear_train_02786.png',
#  'clear_train_02790.png',
#  'clear_train_02802.png',
#  'clear_train_02805.png',
#  'clear_train_02807.png',
#  'clear_train_02813.png',
#  'clear_train_02819.png',
#  'clear_train_02823.png',
#  'clear_train_02828.png',
#  'clear_train_02833.png',
#  'clear_train_02834.png',
#  'clear_train_02839.png',
#  'clear_train_02840.png',
#  'clear_train_02842.png',
#  'clear_train_02847.png',
#  'clear_train_02860.png',
#  'clear_train_02871.png',
#  'clear_train_02872.png',
#  'clear_train_02886.png',
#  'clear_train_02887.png',
#  'clear_train_02891.png',
#  'clear_train_02901.png',
#  'clear_train_02909.png',
#  'clear_train_02916.png',
#  'clear_train_02918.png',
#  'clear_train_02919.png',
#  'clear_train_02929.png',
#  'clear_train_02930.png',
#  'clear_train_02932.png',
#  'clear_train_02934.png',
#  'clear_train_02936.png',
#  'clear_train_02937.png',
#  'clear_train_02939.png',
#  'clear_train_02940.png',
#  'clear_train_02941.png',
#  'clear_train_02948.png',
#  'clear_train_02953.png',
#  'clear_train_02961.png',
#  'clear_train_02994.png',
#  'clear_train_02995.png',
#  'clear_train_02998.png',
#  'clear_train_02999.png',
#  'clear_train_03002.png',
#  'clear_train_03008.png',
#  'clear_train_03011.png',
#  'clear_train_03013.png',
#  'clear_train_04002.png',
#  'clear_train_04007.png',
#  'clear_train_04011.png',
#  'clear_train_04012.png',
#  'clear_train_04014.png',
#  'clear_train_04015.png',
#  'clear_train_04019.png',
#  'clear_train_04020.png',
#  'clear_train_04021.png',
#  'clear_train_04023.png',
#  'clear_train_04024.png',
#  'clear_train_04028.png',
#  'clear_train_04029.png',
#  'clear_train_04030.png',
#  'clear_train_04031.png',
#  'clear_train_04032.png',
#  'clear_train_04033.png',
#  'clear_train_04037.png',
#  'clear_train_04039.png',
#  'clear_train_04043.png',
#  'clear_train_04046.png',
#  'clear_train_04049.png',
#  'clear_train_04052.png',
#  'clear_train_04055.png',
#  'clear_train_04058.png',
#  'clear_train_04059.png',
#  'clear_train_04066.png',
#  'clear_train_04067.png',
#  'clear_train_04068.png',
#  'clear_train_04070.png',
#  'clear_train_04072.png',
#  'clear_train_04073.png',
#  'clear_train_04074.png',
#  'clear_train_04075.png',
#  'clear_train_04076.png',
#  'clear_train_04078.png',
#  'clear_train_04081.png',
#  'clear_train_04082.png',
#  'clear_train_04083.png',
#  'clear_train_04086.png',
#  'clear_train_04087.png',
#  'clear_train_04088.png',
#  'clear_train_04090.png',
#  'clear_train_04092.png',
#  'clear_train_04094.png',
#  'clear_train_04096.png',
#  'clear_train_04097.png',
#  'clear_train_04100.png',
#  'clear_train_04101.png',
#  'clear_train_04102.png',
#  'clear_train_04103.png',
#  'clear_train_04104.png',
#  'clear_train_04108.png',
#  'clear_train_04110.png',
#  'clear_train_04111.png',
#  'clear_train_04112.png',
#  'clear_train_04114.png',
#  'clear_train_04115.png',
#  'clear_train_04117.png',
#  'clear_train_04119.png',
#  'clear_train_04120.png',
#  'clear_train_04122.png',
#  'clear_train_04123.png',
#  'clear_train_04127.png',
#  'clear_train_04130.png',
#  'clear_train_04131.png',
#  'clear_train_04133.png',
#  'clear_train_04135.png',
#  'clear_train_04137.png',
#  'clear_train_04138.png',
#  'clear_train_04139.png',
#  'clear_train_04140.png',
#  'clear_train_04142.png',
#  'clear_train_04143.png',
#  'clear_train_04147.png',
#  'clear_train_04149.png',
#  'clear_train_04151.png',
#  'clear_train_04152.png',
#  'clear_train_04153.png',
#  'clear_train_04157.png',
#  'clear_train_04161.png',
#  'clear_train_04165.png',
#  'clear_train_04168.png',
#  'clear_train_04171.png',
#  'clear_train_04173.png',
#  'clear_train_04176.png',
#  'clear_train_04178.png',
#  'clear_train_04179.png',
#  'clear_train_04180.png',
#  'clear_train_04181.png',
#  'clear_train_04182.png',
#  'clear_train_04192.png',
#  'clear_train_04193.png',
#  'clear_train_04194.png',
#  'clear_train_04196.png',
#  'clear_train_04199.png',
#  'clear_train_04200.png',
#  'clear_train_04201.png',
#  'clear_train_04203.png',
#  'clear_train_04204.png',
#  'clear_train_04206.png',
#  'clear_train_04209.png',
#  'clear_train_04216.png',
#  'clear_train_04221.png',
#  'clear_train_04223.png',
#  'clear_train_04225.png',
#  'clear_train_04227.png',
#  'clear_train_04228.png',
#  'clear_train_04231.png',
#  'clear_train_04236.png',
#  'clear_train_04237.png',
#  'clear_train_04245.png',
#  'clear_train_04246.png',
#  'clear_train_04247.png',
#  'clear_train_04248.png',
#  'clear_train_04250.png',
#  'clear_train_04253.png',
#  'clear_train_04254.png',
#  'clear_train_04255.png',
#  'clear_train_04256.png',
#  'clear_train_04259.png',
#  'clear_train_04260.png',
#  'clear_train_04261.png',
#  'clear_train_04262.png',
#  'clear_train_04265.png',
#  'clear_train_04267.png',
#  'clear_train_04268.png',
#  'clear_train_04274.png',
#  'clear_train_04275.png',
#  'clear_train_04278.png',
#  'clear_train_04282.png',
#  'clear_train_04283.png',
#  'clear_train_04284.png',
#  'clear_train_04286.png',
#  'clear_train_04293.png',
#  'clear_train_04298.png',
#  'clear_train_04299.png',
#  'clear_train_04300.png',
#  'clear_train_04301.png',
#  'clear_train_04302.png',
#  'clear_train_04304.png',
#  'clear_train_04306.png',
#  'clear_train_04308.png',
#  'clear_train_04309.png',
#  'clear_train_04310.png',
#  'clear_train_04312.png',
#  'clear_train_04317.png',
#  'clear_train_04318.png',
#  'clear_train_04319.png',
#  'clear_train_04320.png',
#  'clear_train_04323.png',
#  'clear_train_04327.png',
#  'clear_train_04330.png',
#  'clear_train_04331.png',
#  'clear_train_04332.png',
#  'clear_train_04334.png',
#  'clear_train_04335.png',
#  'clear_train_04336.png',
#  'clear_train_04337.png',
#  'clear_train_04341.png',
#  'clear_train_04343.png',
#  'clear_train_04344.png',
#  'clear_train_04347.png',
#  'clear_train_04348.png',
#  'clear_train_04349.png',
#  'clear_train_04350.png',
#  'clear_train_04351.png',
#  'clear_train_04352.png',
#  'clear_train_04353.png',
#  'clear_train_04354.png',
#  'clear_train_04356.png',
#  'clear_train_04357.png',
#  'clear_train_04359.png',
#  'clear_train_04361.png',
#  'clear_train_04363.png',
#  'clear_train_04364.png',
#  'clear_train_04365.png',
#  'clear_train_04370.png',
#  'clear_train_04373.png',
#  'clear_train_04374.png',
#  'clear_train_04376.png',
#  'clear_train_04377.png',
#  'clear_train_04380.png',
#  'clear_train_04383.png',
#  'clear_train_04386.png',
#  'clear_train_04389.png',
#  'clear_train_04393.png',
#  'clear_train_04394.png',
#  'clear_train_04395.png',
#  'clear_train_04396.png',
#  'clear_train_04398.png',
#  'clear_train_04399.png',
#  'clear_train_04400.png',
#  'clear_train_04403.png',
#  'clear_train_04405.png',
#  'clear_train_04406.png',
#  'clear_train_04407.png',
#  'clear_train_04410.png',
#  'clear_train_04413.png',
#  'clear_train_04414.png',
#  'clear_train_04417.png',
#  'clear_train_04418.png',
#  'clear_train_04419.png',
#  'clear_train_04420.png',
#  'clear_train_04423.png',
#  'clear_train_04425.png',
#  'clear_train_04426.png',
#  'clear_train_04427.png',
#  'clear_train_04428.png',
#  'clear_train_04429.png',
#  'clear_train_04431.png',
#  'clear_train_04433.png',
#  'clear_train_04434.png',
#  'clear_train_04439.png',
#  'clear_train_04440.png',
#  'clear_train_04447.png',
#  'clear_train_04449.png',
#  'clear_train_04455.png',
#  'clear_train_04457.png',
#  'clear_train_04458.png',
#  'clear_train_04461.png',
#  'clear_train_04464.png',
#  'clear_train_04465.png',
#  'clear_train_04467.png',
#  'clear_train_04471.png',
#  'clear_train_04472.png',
#  'clear_train_04474.png',
#  'clear_train_04475.png',
#  'clear_train_04476.png',
#  'clear_train_04478.png',
#  'clear_train_04483.png',
#  'clear_train_04485.png',
#  'clear_train_04486.png',
#  'clear_train_04491.png',
#  'clear_train_04494.png',
#  'clear_train_04495.png',
#  'clear_train_04498.png',
#  'clear_train_04500.png',
#  'clear_train_04502.png',
#  'clear_train_04503.png',
#  'clear_train_04506.png',
#  'clear_train_04507.png',
#  'clear_train_04509.png',
#  'clear_train_04510.png',
#  'clear_train_04511.png',
#  'clear_train_04518.png',
#  'clear_train_04520.png',
#  'clear_train_04522.png',
#  'clear_train_04525.png',
#  'clear_train_04526.png',
#  'clear_train_04527.png',
#  'clear_train_04530.png',
#  'clear_train_04532.png',
#  'clear_train_04535.png',
#  'clear_train_04536.png',
#  'clear_train_04540.png',
#  'clear_train_04545.png',
#  'clear_train_04546.png',
#  'clear_train_04547.png',
#  'clear_train_04550.png',
#  'clear_train_04553.png',
#  'clear_train_04555.png',
#  'clear_train_04557.png',
#  'clear_train_04558.png',
#  'clear_train_04563.png',
#  'clear_train_04567.png',
#  'clear_train_04569.png',
#  'clear_train_04573.png',
#  'clear_train_04577.png',
#  'clear_train_04578.png',
#  'clear_train_04579.png',
#  'clear_train_04580.png',
#  'clear_train_04581.png',
#  'clear_train_04583.png',
#  'clear_train_04584.png',
#  'clear_train_04590.png',
#  'clear_train_04592.png',
#  'clear_train_04596.png',
#  'clear_train_04598.png',
#  'clear_train_04602.png',
#  'clear_train_04605.png',
#  'clear_train_04606.png',
#  'clear_train_04607.png',
#  'clear_train_04608.png',
#  'clear_train_04609.png',
#  'clear_train_04611.png',
#  'clear_train_04612.png',
#  'clear_train_04616.png',
#  'clear_train_04617.png',
#  'clear_train_04619.png',
#  'clear_train_04622.png',
#  'clear_train_04623.png',
#  'clear_train_04625.png',
#  'clear_train_04627.png',
#  'clear_train_04628.png',
#  'clear_train_04634.png',
#  'clear_train_04636.png',
#  'clear_train_04637.png',
#  'clear_train_04638.png',
#  'clear_train_04640.png',
#  'clear_train_04645.png',
#  'clear_train_04650.png',
#  'clear_train_04652.png',
#  'clear_train_04654.png',
#  'clear_train_04656.png',
#  'clear_train_04657.png',
#  'clear_train_04658.png',
#  'clear_train_04659.png',
#  'clear_train_04660.png',
#  'clear_train_04662.png',
#  'clear_train_04665.png',
#  'clear_train_04666.png',
#  'clear_train_04667.png',
#  'clear_train_04668.png',
#  'clear_train_04672.png',
#  'clear_train_04674.png',
#  'clear_train_04680.png',
#  'clear_train_04681.png',
#  'clear_train_04682.png',
#  'clear_train_04686.png',
#  'clear_train_04693.png',
#  'clear_train_04701.png',
#  'clear_train_04705.png',
#  'clear_train_04707.png',
#  'clear_train_04708.png',
#  'clear_train_04713.png',
#  'clear_train_04714.png',
#  'clear_train_04715.png',
#  'clear_train_04716.png',
#  'clear_train_04719.png',
#  'clear_train_04720.png',
#  'clear_train_04725.png',
#  'clear_train_04728.png',
#  'clear_train_04731.png',
#  'clear_train_04733.png',
#  'clear_train_04736.png',
#  'clear_train_04739.png',
#  'clear_train_04741.png',
#  'clear_train_04743.png',
#  'clear_train_04745.png',
#  'clear_train_04753.png',
#  'clear_train_04754.png',
#  'clear_train_04757.png',
#  'clear_train_04760.png',
#  'clear_train_04763.png',
#  'clear_train_04765.png',
#  'clear_train_04766.png',
#  'clear_train_04768.png',
#  'clear_train_04769.png',
#  'clear_train_04771.png',
#  'clear_train_04773.png',
#  'clear_train_04776.png',
#  'clear_train_04777.png',
#  'clear_train_04778.png',
#  'clear_train_04781.png',
#  'clear_train_04783.png',
#  'clear_train_04788.png',
#  'clear_train_04793.png',
#  'clear_train_04794.png',
#  'clear_train_04799.png',
#  'clear_train_04802.png',
#  'clear_train_04805.png',
#  'clear_train_04806.png',
#  'clear_train_04807.png',
#  'clear_train_04809.png',
#  'clear_train_04811.png',
#  'clear_train_04813.png',
#  'clear_train_04814.png',
#  'clear_train_04817.png',
#  'clear_train_04818.png',
#  'clear_train_04820.png',
#  'clear_train_04821.png',
#  'clear_train_04822.png',
#  'clear_train_04823.png',
#  'clear_train_04824.png',
#  'clear_train_04827.png',
#  'clear_train_04828.png',
#  'clear_train_04829.png',
#  'clear_train_04831.png',
#  'clear_train_04836.png',
#  'clear_train_04838.png',
#  'clear_train_04840.png',
#  'clear_train_04845.png',
#  'clear_train_04846.png',
#  'clear_train_04847.png',
#  'clear_train_04849.png',
#  'clear_train_04851.png',
#  'clear_train_04855.png',
#  'clear_train_04856.png',
#  'clear_train_04857.png',
#  'clear_train_04859.png',
#  'clear_train_04860.png',
#  'clear_train_04864.png',
#  'clear_train_04868.png',
#  'clear_train_04869.png',
#  'clear_train_04870.png',
#  'clear_train_04872.png',
#  'clear_train_04873.png',
#  'clear_train_04882.png',
#  'clear_train_04884.png',
#  'clear_train_04885.png',
#  'clear_train_04886.png',
#  'clear_train_04889.png',
#  'clear_train_04890.png',
#  'clear_train_04891.png',
#  'clear_train_04892.png',
#  'clear_train_04894.png',
#  'clear_train_04895.png',
#  'clear_train_04899.png',
#  'clear_train_04900.png',
#  'clear_train_04902.png',
#  'clear_train_04903.png',
#  'clear_train_04904.png',
#  'clear_train_04907.png',
#  ...]

# %% [markdown]
# ### Extract useful params and get average classification error

# %%
degradedIDs = AM_loaded_data['degradedIDs']
dimensions = np.unique(df_decode['dim'])
n_folds = np.unique(df_decode['fold_idx'])
regions = np.unique(df_decode['loader_args'].apply(lambda x: x.get('region')))
dimreduc_methods = np.unique(df_decode['dimreduc_method'])
stimIDs = AM_loaded_data['StimIDs']

# %%
def recursive_defaultdict():
    return defaultdict(recursive_defaultdict)
all_losses = recursive_defaultdict()
 
for dr_method in dimreduc_methods:
    for reg in regions:
        all_losses[dr_method][reg] = np.zeros(len(dimensions))
        for idx, dim in enumerate(dimensions):

            df_decode_filt = df_decode[(df_decode['loader_args'].apply(lambda x: x.get('region')) == reg) & (df_decode['dimreduc_method'] == dr_method) & (df_decode['dim'] == dim)]
            avg_loss = np.mean(df_decode_filt['loss']) # averages loss over k_fold splits
            all_losses[dr_method][reg][idx] = avg_loss

# %% [markdown]
# ## Average classification accuracy in subspaces

# %%
region = 'AM'

FFC_losses = 1 - all_losses['PCA'][region]
FBC_losses = 1 - all_losses['LQGCA'][region]
Diff_losses = FBC_losses - FFC_losses
max_dim_ind = np.argmax(Diff_losses)
max_diff_dim = dimensions[max_dim_ind]


plt.figure(figsize=(10, 5))  # 10 inches wide by 5 inches tall
plt.plot(dimensions, FFC_losses, label="FFC", color='black')
plt.plot(dimensions, FBC_losses, label="FBC", color='red')

plt.legend()
plt.title(f'Region {region} Classification Accuracy')
plt.xticks(dimensions)
plt.xlabel('Dimension')
plt.ylabel('Accuracy')
#plt.axvline(x=max_diff_dim, color=[0, 0, 0, 0.5], linestyle='--') 
plt.axvline(x=21, color=[0, 0, 0, 0.5], linestyle='--') 
plt.show()

"""" 
plt.figure(figsize=(10, 5))  # 10 inches wide by 5 inches tall
plt.plot(dimensions, [np.sum(FFC_losses[0:idx]) for idx, loss in enumerate(FFC_losses) ], label="FFC")
plt.plot(dimensions, [np.sum(FBC_losses[0:idx]) for idx, loss in enumerate(FBC_losses) ], label="FBC")

plt.legend()
plt.title(f'Region {region} Classification Accuracy')
plt.xticks(dimensions[0:-2])
plt.xlabel('Dimension')
plt.ylabel('Accuracy')
plt.show()

"""

plt.figure(figsize=(10, 5))  # 10 inches wide by 5 inches tall
plt.plot(dimensions, Diff_losses, label="FBC - FFC", color='orange')

plt.legend()
plt.title(f'Region {region} dimension with maximim FBC vs FFC Difference: {max_diff_dim}')
plt.xticks(dimensions)
plt.xlabel('Dimension')
plt.ylabel('FBC - FFC Accuracy')
#plt.axvline(x=max_diff_dim, color=[0, 0, 0, 0.5], linestyle='--') 
plt.axvline(x=21, color=[0, 0, 0, 0.5], linestyle='--') 
plt.show()

print(f"Max fold difference: {FBC_losses[max_dim_ind]/FFC_losses[max_dim_ind]}")
# Out:
# Max fold difference: inf
# /tmp/ipykernel_91389/3350273432.py:49: RuntimeWarning: divide by zero encountered in double_scalars
#   print(f"Max fold difference: {FBC_losses[max_dim_ind]/FFC_losses[max_dim_ind]}")

# %%
region = 'ML'

FFC_losses = 1 - all_losses['PCA'][region]
FBC_losses = 1 - all_losses['LQGCA'][region]
Diff_losses = FBC_losses - FFC_losses
max_dim_ind = np.argmax(Diff_losses)
max_diff_dim = dimensions[max_dim_ind]


plt.figure(figsize=(10, 5))  # 10 inches wide by 5 inches tall
plt.plot(dimensions, FFC_losses, label="FFC", color='black')
plt.plot(dimensions, FBC_losses, label="FBC", color='red')

plt.legend()
plt.title(f'Region {region} Classification Accuracy')
plt.xticks(dimensions)
plt.axvline(x=max_diff_dim, color=[0, 0, 0, 0.5], linestyle='--') 
plt.xlabel('Dimension')
plt.ylabel('Accuracy')
plt.show()


plt.figure(figsize=(10, 5))  # 10 inches wide by 5 inches tall
plt.plot(dimensions, Diff_losses, label="FBC - FFC", color='orange')

plt.legend()
plt.title(f'Region {region} dimension with maximum FBC vs FFC Difference: {max_diff_dim}')
plt.xticks(dimensions)
plt.xlabel('Dimension')
plt.ylabel('FBC - FFC Accuracy')
#plt.axvline(x=max_diff_dim, color=[0, 0, 0, 0.5], linestyle='--') 
plt.axvline(x=21, color=[0, 0, 0, 0.5], linestyle='--') 
plt.show()


print(f"Max fold difference: {FBC_losses[max_dim_ind]/FFC_losses[max_dim_ind]}")
# Out:
# Max fold difference: 3.15802382620884

# %%
plt.figure(figsize=(10, 5))  # 10 inches wide by 5 inches tall

region = 'AM'
FFC_losses = 1 - all_losses['PCA'][region]
FBC_losses = 1 - all_losses['LQGCA'][region]
AM_diff_losses = FBC_losses - FFC_losses
max_dim_ind = np.argmax(AM_diff_losses)
max_diff_dim = dimensions[max_dim_ind]
plt.plot(dimensions, AM_diff_losses,label=f"{region}: FBC - FFC", color=[1, 0, 1, 0.5])

region = 'ML'
FFC_losses = 1 - all_losses['PCA'][region]
FBC_losses = 1 - all_losses['LQGCA'][region]
ML_diff_losses = FBC_losses - FFC_losses
max_dim_ind = np.argmax(ML_diff_losses)
max_diff_dim = dimensions[max_dim_ind]
plt.plot(dimensions, ML_diff_losses, color='b', label=f"{region}: FBC - FFC")

"""
Computing the optimal dimension across regions:

    1. For both regions, across all dimensions, find the difference in decoding in FBC and FFC subspaces (specifically, FBC-FFC)
    2. Normalize each area's decoding difference by the maximum decoding difference (this way both regions decoding difference is on the same scale)
    3. Sum across both regions to find dimensions with highest (fraction of each region's total) FBC-FFC decoding difference
    4. Subtract by the per-dimension difference between each region's percent of maximal decoding difference
    5. Find dimension which optimizes this.

"""
ML_perc_max = ML_diff_losses / np.max(ML_diff_losses)
AM_perc_max = AM_diff_losses / np.max(AM_diff_losses)

combined_perc_max = ML_perc_max+AM_perc_max
metric = combined_perc_max - np.abs(ML_perc_max-AM_perc_max)
opt_dim_ind = np.argmax(metric)
opt_dim = dimensions[opt_dim_ind]


plt.legend()
plt.title(f'Optimal dimension for subspace decoding difference across both regions: {opt_dim}')
plt.xticks(dimensions)
plt.xlabel('Dimension')
plt.ylabel('FBC - FFC Accuracy')
#plt.axvline(x=max_diff_dim, color='r', linestyle='--') 
plt.axvline(x=opt_dim, color=[0, 0, 0, 0.5], linestyle='--') 
plt.show()



plt.figure(figsize=(10, 5))  # 10 inches wide by 5 inches tall
plt.plot(dimensions, metric, label="ML: FBC - FFC", color=[0.5, 0.7, 1, 1])
plt.axvline(x=opt_dim, color=[0, 0, 0, 0.5], linestyle='--') 
plt.xticks(dimensions)
plt.title(f'Metric used to find optimal cross region dimension')
plt.ylabel(' (AM+ML subspace difference) - |AM-ML subspace difference|')
plt.show()

print(f"ML max diff percent : {ML_perc_max[opt_dim_ind]}, AM max diff percent: {AM_perc_max[opt_dim_ind]}")

#print(" ")
#for idx, dim in enumerate(dimensions):
#    print(f"Dim: {dim}, ML max diff percent : {np.round(ML_perc_max[idx]*100, 3)}, AM max diff percent: {np.round(AM_perc_max[idx]*100, 3)}")
# Out:
# ML max diff percent : 1.0, AM max diff percent: 0.9983361064890278
