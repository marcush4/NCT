# %% [markdown]
# # This is to see how many units there were, per Area, per Recording

# %%
import pandas as pd
import numpy as np

# %%
file_path = "/home/marcush/Data/AllenData/PerSessionUnitYield.pkl"

loaded_all_unit_counts = pd.read_pickle(file_path)

# %%
loaded_all_unit_counts.keys()
# Out:
# Index(['CA1', 'LP', 'grey', 'LGd', 'PO', 'VISrl', 'VISp', 'VISpm', 'VISl',
#        'VISam', 'APN', 'DG', 'CA3', 'PoT', 'POL', 'SUB', 'VPM', 'NOT', 'TH',
#        'VISal', 'VL', 'Eth', 'VIS', 'LGv', 'SCig', 'MB', 'VISmma', 'PIL', 'PP',
#        'MGv', 'ProS', 'SGN', 'IGL', 'VPL', 'CA2', 'IntG', 'LD', 'MGm', 'PPT',
#        'MRN', 'VISli', 'MGd', 'OP', 'ZI', 'VISmmp'],
#       dtype='object')

# %% [markdown]
# ### Decoding accuracy for VISp saturates around 50 dimensions (units).
# ### Number of sessions with greater than 50 units:

# %%
print("Unit counts per session (sorted): ")
print(np.sort(loaded_all_unit_counts['VISp'].values)[::-1])

print("Number of valid sessions: ")


print(sum(loaded_all_unit_counts['VISp'].values > 50))
# Out:
# Unit counts per session (sorted):
# [110 102  94  93  92  88  85  85  84  80  75  75  75  73  72  63  60  58
#   52  52  51  49  47  45  41  40  37  36  35  33  19  14]
# Number of valid sessions:
# 21

# %%
loaded_all_unit_counts.sort_values(by='VISp', ascending=False).head(21).index.tolist()
# Out:
# [732592105,
#  754312389,
#  798911424,
#  791319847,
#  754829445,
#  760693773,
#  757216464,
#  797828357,
#  762120172,
#  757970808,
#  799864342,
#  762602078,
#  755434585,
#  763673393,
#  760345702,
#  750332458,
#  715093703,
#  759883607,
#  719161530,
#  750749662,
#  756029989]

# %%
loaded_all_unit_counts.sort_values(by='CA1', ascending=False).head(5).index.tolist()
# Out:
# [715093703, 761418226, 754312389, 798911424, 763673393]

# %% [markdown]
# ## Next Region to include: VISl
#
# ### - VISli would be ideal as it's highest amoung the ventral visual areas, but there's only one session for it.

# %%
region = 'VISl'
print(loaded_all_unit_counts.sort_values(by=region, ascending=False).head(5)[region])
print(loaded_all_unit_counts.sort_values(by=region, ascending=False).head(5)[region].index.tolist())
# Out:
# 798911424    78.0
# 762120172    74.0
# 797828357    58.0
# 791319847    56.0
# 757216464    53.0
# Name: VISl, dtype: float64
# [798911424, 762120172, 797828357, 791319847, 757216464]

# %%
loaded_all_unit_counts
# Out:
#              CA1     LP   grey   LGd    PO  VISrl  VISp  VISpm  VISl  VISam  \
# 715093703  145.0  139.0  117.0  82.0  76.0   76.0    60   50.0  42.0   30.0
# 719161530  108.0   28.0   19.0  71.0   5.0   10.0    52   18.0  40.0   37.0
# 721123822   71.0   69.0    NaN   NaN   NaN   46.0    41    NaN  27.0   39.0
# 732592105    NaN    NaN  459.0   NaN   NaN   64.0   110   66.0  40.0    NaN
# 737581020    NaN    NaN  410.0   NaN   NaN   67.0    40   13.0  22.0    NaN
# 739448407    NaN    NaN  347.0   NaN   NaN   70.0    19    NaN  36.0   56.0
# 742951821    NaN    NaN  554.0   NaN   NaN   79.0    33   23.0  52.0    NaN
# 743475441   20.0  131.0    NaN  42.0  17.0   68.0    45    NaN  19.0   53.0
# 744228101  112.0   84.0    NaN   1.0   NaN   26.0    35    NaN  26.0    NaN
# 746083955    7.0    NaN  292.0  34.0   NaN   35.0    14  115.0  17.0    NaN
# 750332458   16.0    NaN  558.0   4.0   NaN   44.0    63   19.0  38.0   60.0
# ...
