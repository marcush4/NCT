# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from neurosim.models.ssr import StateSpaceRealization as SSR
from neurosim.models.varma import gen_var1_connectivity
from tqdm import tqdm
import pdb
from scipy.stats import ortho_group

# %%
import jax
import jax.numpy as jnp

# %%
import sys
sys.path.append('../..')
from utils import calc_loadings
from riccati import riccati_opt

# %% [markdown]
# ### Testing Riccati Equation solver implementation

# %%
from scipy.stats import ortho_group

# %%
# Test on the minimal positive real realization problem
ssdim = 10
projdim = 2
noise_strength = 1

A = 1/5 * np.random.normal(size=(ssdim, ssdim))

if max(np.abs(np.linalg.eigvals(A))) >= 1:
    while max(np.abs(np.linalg.eigvals(A))) >= 1:
        A = 1/5 * np.random.normal(size=(ssdim, ssdim))

# Non-random B!
B = np.random.normal(size=(ssdim, ssdim))
P = scipy.linalg.solve_discrete_lyapunov(A, B @ B.T)

C = np.eye(ssdim)
D = noise_strength * np.eye(ssdim)

Cbar = (C @ P @ A.T + D @ B.T)

# Projection matrix
V = ortho_group.rvs(ssdim)[:, 0:projdim].T
Lambda0 = V @ (C @ P @ C.T + D @ D.T) @ V.T

# %%
# Does the ambient P satisfy the ricatti equation?

# %%
PP = scipy.linalg.solve_discrete_are(A.T, (V @ C).T, np.zeros(A.shape), -Lambda0, s=-(V @ Cbar).T)

# %%
# Verify correctness of solution

# %%
riccati(PP, A, V @ C, V @ Cbar, Lambda0)
# Out:
# array([[-9.54791801e-15,  5.77315973e-15, -8.88178420e-15,
#         -7.10542736e-15,  2.66453526e-15, -2.66453526e-15,
#         -6.77236045e-15,  1.33226763e-15, -4.77395901e-15,
#         -2.99760217e-15],
#        [ 5.55111512e-15, -1.33226763e-14,  4.88498131e-15,
#          1.33226763e-15,  0.00000000e+00, -1.55431223e-15,
#          3.10862447e-15, -9.10382880e-15,  1.11022302e-15,
#          0.00000000e+00],
#        [-8.65973959e-15,  5.32907052e-15,  2.22044605e-15,
#         -1.06581410e-14, -1.11022302e-15,  1.77635684e-15,
#         -6.10622664e-16,  2.66453526e-15, -8.88178420e-16,
#          2.66453526e-15],
#        [-6.88338275e-15,  2.22044605e-15, -1.11022302e-14,
#         -1.73194792e-14,  0.00000000e+00, -1.99840144e-15,
#         -1.55431223e-15, -8.88178420e-16,  4.44089210e-16,
#          4.21884749e-15],
#        [ 2.66453526e-15,  2.22044605e-16, -8.88178420e-16,
#         -4.44089210e-16,  5.32907052e-15,  2.22044605e-15,
#         -1.88737914e-15,  8.88178420e-16, -7.77156117e-16,
#         -1.66533454e-16],
#        [-2.99760217e-15, -1.22124533e-15,  1.22124533e-15,
#         -2.22044605e-15,  1.99840144e-15, -1.99840144e-15,
#         -2.66453526e-15,  1.77635684e-15, -1.24900090e-15,
#         -5.55111512e-16],
#        [-7.32747196e-15,  3.77475828e-15, -1.08246745e-15,
#         -1.99840144e-15, -1.99840144e-15, -2.99760217e-15,
#         -7.99360578e-15, -3.10862447e-15, -5.55111512e-16,
#         -2.44249065e-15],
#        [ 1.11022302e-15, -9.99200722e-15,  3.10862447e-15,
#         -4.44089210e-16,  1.33226763e-15,  1.77635684e-15,
#         -3.99680289e-15, -8.88178420e-15,  6.10622664e-15,
#          2.99760217e-15],
#        [-4.88498131e-15,  1.33226763e-15, -1.11022302e-15,
#          6.66133815e-16, -8.88178420e-16, -1.33226763e-15,
#         -2.22044605e-16,  5.77315973e-15,  2.22044605e-16,
#         -4.82947016e-15],
#        [-2.94209102e-15, -2.22044605e-16,  2.99760217e-15,
#          4.82947016e-15, -2.22044605e-16, -3.88578059e-16,
#         -2.22044605e-15,  2.44249065e-15, -4.55191440e-15,
#         -1.55431223e-15]])

# %%
def riccati(x, a, c, cbar, j):
    
    return a @ x @ a.T - x + (cbar.T - a @ x @ c.T) @ np.linalg.inv(j - c @ x @ c.T) @ (cbar.T - a @ x @ c.T).T

# %%
Delta = scipy.linalg.sqrtm(Lambda0 - V @ C @ PP @ C.T @ V.T)
BB = ((V @ Cbar).T - A @ PP @ (V @ C).T) @ np.linalg.inv(Delta)
DD = Delta

# %%
ssm_base = SSR(A=A, B=B, C=C, D=noise_strength*np.eye(ssdim))
ssm_proj1 = SSR(A=A, B=B, C=C, D=noise_strength*np.eye(ssdim))
ssm_proj2 = SSR(A=A, B=BB, C=V @ C, D=DD)

# %%
ccm0 = ssm_base.autocorrelation(10)

# %%
V @ ccm0[0, ...] @ V.T
# Out:
# array([[20.49850374,  5.51089172],
#        [ 5.51089172, 29.34478341]])

# %%
ccm0
# Out:
# array([[[ 2.50811834e+01,  5.18248254e+00, -3.98015859e+00,
#           9.37358710e+00, -4.37396773e+00,  8.66091227e-01,
#          -3.64542462e-01, -7.95389526e+00, -1.00728609e+01,
#          -3.72680933e+00],
#         [ 5.18248254e+00,  3.22002133e+01, -8.43767213e+00,
#           1.85943086e+00, -7.23394150e+00,  1.19538624e+00,
#           3.03002188e+00,  1.46484256e+00, -6.04340576e+00,
#           3.63480148e+00],
#         [-3.98015859e+00, -8.43767213e+00,  1.44152268e+01,
#           5.64734706e+00,  8.12403010e-01,  3.18404801e-01,
#           1.22828381e+00, -4.75735243e+00,  1.41968795e+00,
#           4.30581518e+00],
#         [ 9.37358710e+00,  1.85943086e+00,  5.64734706e+00,
#           2.77553833e+01, -2.82273589e+00,  1.58361114e+00,
#           2.28744088e+00, -7.34162690e+00,  4.76142583e+00,
#           6.82534955e+00],
#         [-4.37396773e+00, -7.23394150e+00,  8.12403010e-01,
#          -2.82273589e+00,  2.32636127e+01, -4.39101078e+00,
#           4.72710930e+00, -4.26815699e+00,  8.87595902e+00,
#          -2.56107290e+00],
#         [ 8.66091227e-01,  1.19538624e+00,  3.18404801e-01,
#           1.58361114e+00, -4.39101078e+00,  1.28885649e+01,
#           6.66194251e-01, -8.32189886e-01, -4.08632795e+00,
#           6.79053846e+00],
#         [-3.64542462e-01,  3.03002188e+00,  1.22828381e+00,
#           2.28744088e+00,  4.72710930e+00,  6.66194251e-01,
#           2.52217282e+01, -6.93047149e+00,  5.89119677e+00,
#           2.07809415e+00],
#         [-7.95389526e+00,  1.46484256e+00, -4.75735243e+00,
#          -7.34162690e+00, -4.26815699e+00, -8.32189886e-01,
#          -6.93047149e+00,  2.01269514e+01,  3.29825585e+00,
#          -6.18012692e-01],
#         [-1.00728609e+01, -6.04340576e+00,  1.41968795e+00,
#           4.76142583e+00,  8.87595902e+00, -4.08632795e+00,
#           5.89119677e+00,  3.29825585e+00,  3.15818451e+01,
#           4.59247035e+00],
#         [-3.72680933e+00,  3.63480148e+00,  4.30581518e+00,
#           6.82534955e+00, -2.56107290e+00,  6.79053846e+00,
#           2.07809415e+00, -6.18012692e-01,  4.59247035e+00,
#           2.43186577e+01]],
#
#        [[-5.60185140e+00, -7.30393745e+00,  2.27191628e+00,
#          -3.10448311e-01,  1.84426588e+00,  1.56127408e+00,
#           3.68725514e+00,  1.98368750e+00,  5.80100022e+00,
#           2.54457711e+00],
#         [ 1.11654437e+01,  7.95381784e-01,  2.60541828e+00,
#           1.14493202e+01, -3.29947431e+00, -1.19710551e+00,
#          -5.33082171e+00, -2.35648619e+00, -9.94176178e+00,
#          -1.13789476e+00],
#         [-9.19074791e+00, -5.15230121e+00,  7.27365070e-01,
#          -3.78828289e-01,  7.06473934e+00, -3.85502387e+00,
#           1.68855107e-01,  5.51887758e+00,  6.86761422e+00,
#          -1.99550488e-02],
#         [-1.16759212e+01, -7.83488720e+00,  6.43952973e+00,
#           3.94788087e+00,  1.05621114e+00, -3.53358023e+00,
#          -7.60677795e+00,  1.02886107e+01,  1.62009460e+01,
#           8.88326484e+00],
#         [-4.13608271e-01, -5.04464135e+00,  2.50976783e+00,
#          -6.87709061e+00,  4.98720615e+00,  5.28433302e+00,
#           1.19848414e+00, -2.32932239e+00, -5.78460023e-01,
#          -1.31996516e+00],
#         [-4.46211044e+00,  5.73049561e+00, -1.94409926e+00,
#           6.30906930e-01, -5.10645738e+00,  5.46880617e+00,
#           1.98954795e+00,  4.68373305e+00,  1.22929303e+00,
#           5.68096974e+00],
#         [-4.30495480e+00,  4.15691184e+00,  2.37921999e+00,
#          -3.39927557e+00, -4.04957694e+00,  3.56423349e+00,
#          -4.56256650e+00,  3.63384414e+00, -1.02971823e+01,
#           2.90547133e-01],
#         [ 6.76503485e+00,  1.06900776e+01,  6.08870732e-01,
#           8.86379930e+00, -1.22359599e+00, -2.21859982e+00,
#           3.30475573e+00, -9.13207121e+00,  8.34618879e-03,
#           4.44820057e+00],
#         [-1.38264819e+00,  2.43587908e+00, -3.23860151e+00,
#           1.11771381e+00, -2.35734857e+00, -7.16341640e-01,
#          -6.49809544e+00,  6.12398860e+00,  9.51375233e+00,
#          -1.89771324e+00],
#         [ 3.13205817e+00,  4.99369222e+00, -1.33840477e+00,
#           1.27712232e+01, -4.56064108e-01,  3.05323543e+00,
#           3.61484370e+00,  1.63251007e+00,  1.28543936e+01,
#           6.54501880e+00]],
#
#        [[-3.75089861e+00,  3.25941008e+00, -1.83994429e+00,
#          -3.10065401e+00, -2.81693172e+00,  2.33395555e+00,
#          -3.16266713e-02,  3.08458379e+00,  2.16327449e+00,
#           1.41469128e+00],
#         [-6.50826835e+00, -7.87245834e+00,  4.72490179e+00,
#           4.54012232e-01,  3.68915609e+00, -3.84485130e+00,
#          -1.33982059e+00,  2.77135834e+00,  5.81658782e+00,
#           3.76569035e+00],
#         [ 2.70940480e+00,  2.35669138e+00,  2.39350088e+00,
#           1.29307545e+00,  1.48683950e+00, -1.33380835e+00,
#          -9.64307355e-01, -4.49345589e+00,  8.44562593e-01,
#           1.53248667e+00],
#         [ 1.34294720e+00,  2.10740714e+00, -8.79732606e-01,
#           7.86733976e+00,  2.19364635e+00, -4.68614484e+00,
#          -1.30127098e+00,  2.50636579e-01,  1.48228330e+01,
#           2.79134829e+00],
#         [-1.15127656e+00,  5.47771013e-01, -2.20470433e+00,
#          -5.30384420e+00,  4.65967553e-01,  3.96432468e+00,
#           3.58364608e+00, -2.43432248e-01, -2.99223276e+00,
#          -1.61168744e+00],
#         [ 1.06651399e+00,  8.33089418e+00, -6.43589573e-01,
#           4.46200917e+00, -6.17303026e+00,  1.44425791e+00,
#          -2.17451776e+00,  1.47044138e+00, -1.86091962e+00,
#           4.17259509e+00],
#         [ 4.74422093e+00,  1.13882948e+00, -1.39009412e-01,
#           3.49654764e+00,  5.86567231e-01, -1.74155094e+00,
#           9.37334481e-01, -2.89543810e+00, -4.27352530e+00,
#          -6.25730340e-01],
#         [ 4.81507422e-01, -6.65648488e+00,  2.57345777e+00,
#           4.24417245e+00,  2.95187499e+00, -1.46796114e+00,
#          -2.59832288e+00,  2.56250367e+00,  2.42833627e+00,
#          -7.38598744e-01],
#         [ 4.78961447e+00,  9.44792203e-01, -1.81334323e+00,
#           4.06896941e+00, -1.13363533e+00, -2.52307765e+00,
#          -1.81139173e+00, -1.01567648e+00,  3.50336446e+00,
#          -1.24690919e+00],
#         [-2.46790847e+00,  1.93363083e+00,  6.28971268e-01,
#           5.95438569e+00, -4.13615623e+00, -4.63223741e-01,
#          -6.02319214e+00,  6.23292798e+00,  8.48693707e+00,
#           4.19572164e+00]],
#
#        [[ 3.42338099e+00,  4.45506481e+00, -2.12750599e+00,
#           2.47844200e+00, -3.02579761e+00,  6.18407580e-01,
#          -4.17672833e-01, -4.39955962e-01, -2.08060735e+00,
#          -4.92006216e-01],
#         [-1.19478268e+00, -2.25616879e-01,  5.00299926e-01,
#           9.39679462e-01,  2.81921110e+00, -1.58987265e+00,
#           6.28935835e-01, -5.97330926e-01,  6.34348072e+00,
#           1.13552433e+00],
#         [ 1.37984129e+00, -4.93294313e+00,  1.50727960e-01,
#           1.66085933e+00,  3.96068695e+00, -1.11736271e+00,
#           5.83355053e-01,  3.18915415e-02,  2.58049270e+00,
#          -2.38112680e+00],
#         [ 1.63781770e+00, -3.04034994e+00,  6.02517620e-01,
#           5.18604844e+00,  1.81174750e+00, -2.94659088e+00,
#          -3.37725861e+00,  1.33994102e+00,  9.15828139e+00,
#          -3.23671639e-01],
#         [ 2.78301824e-01,  4.23588038e+00, -1.10704719e+00,
#          -3.00733446e+00, -3.21806951e+00,  3.43299893e+00,
#           1.07694927e+00, -6.91834323e-01, -6.70657023e+00,
#           1.75006761e-02],
#         [ 1.98397453e+00,  1.07200581e+00,  7.74113001e-01,
#           6.42878606e+00, -1.27859719e+00, -2.11324312e+00,
#          -2.25765447e+00,  1.00870722e+00,  1.49920739e+00,
#           1.93114184e+00],
#         [-2.21065328e+00, -2.73515930e+00,  2.63301686e+00,
#          -3.07277608e-01,  1.66428511e+00, -7.58630234e-01,
#          -4.97298229e-01,  1.07733092e-01,  2.34730867e-01,
#           1.22126888e+00],
#         [-3.44375876e+00, -2.21155254e+00,  1.42121024e+00,
#          -9.37077206e-01,  1.84838047e+00, -1.66342244e+00,
#          -4.75299075e-01,  8.00045974e-01,  5.67326430e+00,
#           1.86261977e+00],
#         [-1.19823357e+00, -2.72362403e+00,  4.55013594e-01,
#           3.79924478e-01,  5.97865763e-01, -1.31905172e+00,
#          -1.12933437e+00,  1.31067380e+00,  3.56853761e+00,
#          -1.93862919e-02],
#         [ 1.62658121e+00,  9.79947468e-01, -4.87428195e-01,
#           6.71539808e+00, -7.88405210e-01, -3.53299759e+00,
#          -2.72510379e+00,  1.56714576e+00,  8.17740937e+00,
#           2.02685906e+00]],
#
#        [[ 1.18735662e-01, -1.81623119e-01,  6.06468160e-01,
#           1.34547702e+00, -1.13586350e+00, -5.10008723e-01,
#          -1.22049087e+00,  7.13998231e-01, -7.47712955e-01,
#           6.60967638e-01],
#         [ 1.48888817e+00, -1.13125333e+00, -3.09564217e-01,
#           1.30066804e+00,  1.27567430e+00, -4.53314914e-01,
#          -5.86166764e-01, -1.37438537e-01,  2.57053151e+00,
#          -1.24502886e+00],
#         [-2.65931088e+00, -1.40956891e+00,  8.87497972e-01,
#          -2.92529371e+00,  7.45961204e-01,  2.97827550e-01,
#          -1.04965791e-01,  3.07712459e-01,  1.70997068e+00,
#           5.81457396e-01],
#         [-9.96952589e-01, -3.35796359e+00,  5.26600847e-02,
#           9.82368893e-01,  1.81695640e+00, -2.17613976e+00,
#          -1.36157992e+00,  1.40140145e+00,  7.58754639e+00,
#          -1.52566836e-01],
#         [ 1.11425672e+00,  2.32547307e+00, -5.37274878e-01,
#          -8.03344556e-03, -2.00073045e+00,  1.40806812e+00,
#           6.48933771e-01, -3.51954223e-01, -5.33145832e+00,
#           3.61227630e-02],
#         [-1.24964605e+00, -2.02571705e+00,  1.96336691e+00,
#           3.17113551e+00,  1.20463243e+00, -2.64855794e+00,
#          -1.92165957e+00,  1.09007015e+00,  5.15099888e+00,
#           2.08086197e+00],
#         [-3.32690867e-01, -9.14782697e-01,  2.13369452e-01,
#          -7.59366144e-02,  1.68214949e+00, -4.37180652e-01,
#           6.97802017e-01, -3.47850306e-01,  1.58287645e+00,
#          -5.60564552e-02],
#         [ 1.18870123e+00,  5.30393445e-02, -8.54038271e-01,
#           1.00291333e+00,  1.10778013e+00, -4.08734954e-01,
#           3.02461796e-01, -4.16534023e-01,  2.75175051e+00,
#          -8.48571546e-01],
#         [-4.77072712e-01, -2.29672347e-01, -4.72386181e-01,
#          -2.67587413e-01,  2.91603801e-01, -4.85688106e-01,
#          -1.62538203e-02,  2.96785043e-01,  2.46011331e+00,
#          -6.92273943e-02],
#         [-1.47144062e-01, -1.96921760e+00,  8.64833566e-01,
#           3.95565417e+00,  9.51776914e-01, -2.89418253e+00,
#          -2.49130016e+00,  1.40363912e+00,  7.43290522e+00,
#           1.08026375e+00]],
#
#        [[-6.01609503e-01, -3.57646467e-01,  4.45432566e-01,
#           7.69651979e-01,  2.97652420e-01, -8.44300210e-01,
#          -2.28126592e-01,  2.99694004e-01,  1.37840568e+00,
#           7.73604496e-01],
#         [-5.50800484e-01, -1.29299446e+00, -2.30779901e-02,
#          -7.09628177e-01,  4.33843249e-01, -1.83888963e-01,
#          -2.98333022e-01,  4.25452554e-01,  1.52025607e+00,
#          -3.43092419e-01],
#         [ 1.10608311e+00,  7.56962515e-01, -1.30415174e+00,
#          -3.64450815e-01,  1.83681535e-01,  5.97841662e-01,
#           1.01573325e+00, -5.13778983e-01, -2.72004319e-01,
#          -1.13013636e+00],
#         [-1.81623578e-01, -7.02034402e-01, -7.88501089e-01,
#          -6.63390768e-02,  5.97430836e-01, -6.56120732e-01,
#          -3.33643557e-01,  4.32700660e-01,  4.15389101e+00,
#          -5.42654672e-01],
#         [-4.10699651e-01,  9.05860160e-01,  7.49245585e-01,
#           1.50042190e-01, -9.19749734e-01,  3.01988233e-01,
#          -6.32844384e-02, -4.78423415e-02, -2.56375336e+00,
#           1.04062511e+00],
#         [-1.94133904e-01, -1.78662519e+00,  5.08350780e-01,
#           2.08037493e+00,  1.96767873e+00, -1.93957676e+00,
#          -7.32161340e-01,  3.90720304e-01,  5.48280780e+00,
#           3.73152827e-01],
#         [ 4.50425430e-02, -2.81138723e-01,  6.86568263e-02,
#          -3.13683511e-01,  4.55758209e-01,  1.72231197e-01,
#           1.98722130e-02, -2.01972378e-01,  3.77088384e-01,
#          -2.90569726e-01],
#         [ 6.00956362e-02, -7.02560313e-01, -8.24383342e-02,
#          -2.45789349e-01,  2.47924967e-02,  3.66974641e-02,
#          -5.12450278e-01,  2.94583909e-01,  7.72641022e-01,
#          -4.64814001e-01],
#         [ 5.19236561e-01,  1.92491004e-01, -5.29042413e-01,
#           1.35068506e-01, -1.77683623e-01,  1.56486778e-02,
#          -1.34074479e-01,  2.72753493e-02,  5.81285932e-01,
#          -4.99884931e-01],
#         [-2.51461966e-01, -2.08566274e+00,  9.70885020e-02,
#           1.84336588e+00,  1.49639119e+00, -2.03239979e+00,
#          -1.17311720e+00,  8.87913266e-01,  6.28518990e+00,
#           6.98436293e-02]],
#
#        [[ 7.41361820e-02, -2.49123367e-01,  1.85931830e-01,
#           7.31635044e-01,  4.46950866e-01, -5.07872192e-01,
#          -2.56030058e-01,  2.03380629e-02,  1.31901419e+00,
#           1.49497084e-01],
#         [-7.86050484e-02,  1.90297326e-01, -5.02053948e-01,
#          -5.82465490e-01, -7.69712440e-02,  1.96992178e-01,
#           2.71235291e-01,  7.91367985e-03,  4.24927043e-01,
#          -2.83019160e-01],
#         [-2.49572713e-02,  4.17287310e-01, -7.81013742e-02,
#          -8.05844236e-01, -7.97624734e-01,  6.92237224e-01,
#          -1.44250111e-01,  3.02119741e-02, -1.49094995e+00,
#          -1.66028203e-01],
#         [ 4.77630459e-01, -5.48205541e-02, -8.38131629e-01,
#          -1.53909457e-01, -2.38765164e-01,  3.57376141e-02,
#          -2.25470851e-01,  2.46437133e-01,  1.21661573e+00,
#          -7.75214837e-01],
#         [ 2.48856679e-02,  1.72789829e-01,  4.85734225e-01,
#           7.96091080e-01,  1.97243487e-01, -2.85612062e-01,
#           6.72604056e-02, -1.54317478e-01, -4.38402750e-01,
#           5.55466363e-01],
#         [-8.64935871e-02, -1.42085500e+00,  7.71416527e-02,
#           6.40300517e-01,  1.16035008e+00, -9.15632825e-01,
#          -6.35029084e-01,  3.28506408e-01,  3.66490959e+00,
#          -2.82820579e-01],
#         [ 7.91364754e-02, -1.98160669e-01, -1.84378811e-01,
#          -3.45894683e-01,  1.17951918e-01,  1.77730172e-01,
#           1.53809181e-01, -2.63156963e-02, -8.33076251e-02,
#          -3.09011484e-01],
#         [-1.31202369e-01, -7.80788008e-02, -3.49330335e-01,
#          -4.28171954e-01, -7.27854333e-02,  5.83896481e-02,
#           1.46210725e-01,  1.24965487e-01,  3.37627558e-01,
#          -1.99385507e-01],
#         [ 3.31511567e-02, -6.65944164e-02, -1.85753478e-01,
#          -1.66754884e-01, -2.51321349e-01,  4.22770336e-02,
#          -1.31237213e-01,  1.55586546e-01,  1.64512171e-02,
#          -1.76253636e-01],
#         [-9.18897899e-02, -1.13655832e+00, -3.03903262e-01,
#           4.90842739e-01,  7.90922258e-01, -9.07049034e-01,
#          -6.27535192e-01,  4.68759639e-01,  3.90172068e+00,
#          -3.72252597e-01]],
#
#        [[ 3.11921293e-02, -5.25361578e-01,  7.41788616e-02,
#           3.06866560e-01,  3.88529550e-01, -3.27946530e-01,
#          -2.18093989e-01,  1.07468608e-01,  1.02382536e+00,
#          -9.26105008e-02],
#         [ 2.48309894e-01,  4.04892221e-01, -3.27253955e-01,
#          -2.31181563e-01, -4.09439485e-01,  3.08033661e-01,
#           4.11958390e-02, -2.19105004e-02, -5.17600345e-01,
#          -2.44082765e-01],
#         [ 9.31263766e-02,  3.97459863e-01, -2.33985438e-01,
#          -2.26304898e-01, -3.59402804e-01,  2.54989109e-01,
#           2.91248995e-01, -4.57918773e-02, -9.67984511e-01,
#          -4.07446968e-02],
#         [ 5.18033996e-02,  1.53431829e-01, -4.56385087e-01,
#          -3.96313259e-01, -5.09119934e-01,  1.72348146e-01,
#          -9.76148375e-02,  2.12313866e-01,  1.96688171e-02,
#          -2.97180779e-01],
#         [-1.38657837e-01, -3.56629353e-01,  5.01041413e-01,
#           5.04589000e-01,  4.39336799e-01, -3.39177335e-01,
#          -1.82186278e-01, -2.96609625e-02,  4.60156862e-01,
#           3.29974746e-01],
#         [-6.44883126e-03, -7.48106270e-01, -3.59108255e-01,
#          -1.10809383e-01,  4.85329042e-01, -3.03349424e-01,
#          -1.74723299e-01,  2.33781170e-01,  1.97277335e+00,
#          -4.77551777e-01],
#         [-8.92622378e-02,  1.61608343e-01, -9.71334874e-02,
#          -3.73628788e-01, -1.69340208e-01,  2.25692295e-01,
#           1.05197794e-01, -2.31902011e-02, -3.51434460e-01,
#          -4.90034422e-02],
#         [ 7.01090608e-02,  3.59043796e-01, -2.20891469e-01,
#          -2.15755840e-01, -3.14899200e-01,  2.05826884e-01,
#           4.67716176e-02, -1.38887450e-02, -2.84693305e-01,
#          -9.09694430e-02],
#         [-3.52987386e-02,  1.45878794e-01, -1.32013554e-01,
#          -1.28309002e-01, -1.85109473e-01,  4.70337771e-02,
#           3.44770606e-02,  4.17967742e-02, -8.37954112e-02,
#          -1.49506236e-02],
#         [ 1.42081866e-01, -4.75598501e-01, -5.31589643e-01,
#          -6.04911137e-02,  1.75023932e-01, -2.49243406e-01,
#          -2.42569764e-01,  2.76615800e-01,  1.80726525e+00,
#          -5.36685074e-01]],
#
#        [[-1.01394059e-01, -2.86527938e-01, -3.39474481e-02,
#          -5.16135213e-02,  1.98777675e-01, -1.31878218e-01,
#          -6.28733005e-02,  7.82845957e-02,  6.74877239e-01,
#          -7.59237191e-02],
#         [ 5.19882512e-02,  2.09758406e-01, -1.02678451e-01,
#          -1.21027742e-01, -3.07653850e-01,  1.47148474e-01,
#           1.72559796e-02,  2.91496190e-02, -5.22342766e-01,
#          -2.77560578e-02],
#         [-5.01070421e-02,  3.60590805e-01,  8.78782184e-02,
#          -6.60178664e-02, -2.95876717e-01,  1.59630941e-01,
#           1.64700262e-02, -5.47302492e-02, -6.80518009e-01,
#           1.77332351e-01],
#         [ 7.45216155e-02,  3.66532348e-01, -2.81200021e-01,
#          -1.75181603e-01, -4.32825437e-01,  1.53506581e-01,
#           3.64141658e-02,  5.81959328e-02, -3.54923680e-01,
#          -8.19825443e-02],
#         [-7.59225708e-02, -4.40168246e-01,  1.95003344e-01,
#           2.50991944e-01,  4.80271835e-01, -2.75380349e-01,
#          -5.71150691e-02,  3.05534353e-03,  7.48542427e-01,
#           5.20912894e-02],
#         [ 2.01984735e-02, -5.74240396e-02, -3.92456017e-01,
#          -3.71286283e-01, -9.74249829e-02,  9.10499838e-02,
#          -2.68155416e-02,  1.18561132e-01,  5.82594607e-01,
#          -3.38894186e-01],
#         [ 9.34813466e-02,  2.21865752e-01, -1.06727404e-01,
#          -9.62679764e-02, -1.68623967e-01,  1.53012929e-01,
#           9.35069991e-02, -4.66735962e-02, -4.19626552e-01,
#          -5.19572400e-02],
#         [ 1.25950725e-01,  1.84218268e-01, -1.08212431e-01,
#          -9.94432979e-03, -2.20643713e-01,  1.00057430e-01,
#           1.06470690e-02,  5.67597641e-03, -3.71393661e-01,
#          -5.77660320e-02],
#         [ 6.30485307e-02,  1.49196019e-01, -6.06653923e-02,
#           1.27380523e-02, -1.36349272e-01,  4.27327815e-02,
#          -9.69967570e-04, -3.79712505e-03, -1.65460073e-01,
#          -1.00347665e-02],
#         [ 5.51349437e-02,  4.37387229e-03, -4.19123364e-01,
#          -3.03992582e-01, -2.34972060e-01,  6.89432784e-02,
#          -8.23189363e-02,  1.65636257e-01,  4.80797338e-01,
#          -3.22619681e-01]],
#
#        [[ 2.91658994e-02, -3.19779965e-02, -1.24187897e-01,
#          -8.02478915e-02,  2.18694421e-02,  9.55357125e-03,
#           6.96877424e-03,  1.99327341e-02,  2.43224977e-01,
#          -1.16468477e-01],
#         [-1.72165731e-02,  1.66033786e-01,  4.05766690e-03,
#          -1.36217209e-02, -1.56210008e-01,  4.82866509e-02,
#           2.28912252e-02, -4.87793239e-03, -3.00023730e-01,
#           7.69383711e-02],
#         [ 7.87235145e-02,  7.75853619e-02,  5.74890637e-02,
#           1.61923012e-01, -2.27214579e-02, -1.66097867e-02,
#           2.60589003e-02, -3.79490828e-02, -2.63855821e-01,
#           6.49645410e-02],
#         [ 7.72271929e-02,  2.54921907e-01, -8.11840209e-02,
#           1.31242622e-02, -2.80488119e-01,  7.53802832e-02,
#          -1.63515937e-02,  1.58494321e-02, -3.69013659e-01,
#           1.60584993e-02],
#         [-6.85957305e-02, -2.59023942e-01,  4.57654203e-02,
#           2.09039354e-03,  2.59818202e-01, -1.02603767e-01,
#          -3.62263289e-02,  1.28424486e-02,  5.32159010e-01,
#          -4.08797272e-02],
#         [ 1.18445727e-01,  2.13540557e-01, -3.16764805e-01,
#          -2.44682835e-01, -2.96243086e-01,  1.79355210e-01,
#           3.63890326e-02,  4.75989049e-02, -1.63589745e-01,
#          -2.14768011e-01],
#         [ 4.44618629e-03,  1.14766070e-01,  1.53832195e-02,
#          -3.29357809e-02, -1.22268363e-01,  7.16034619e-02,
#           9.73927110e-03, -1.19902449e-02, -3.05060549e-01,
#           3.78162916e-02],
#         [-3.28905887e-02,  8.39114033e-02,  2.52129458e-02,
#          -1.03314654e-02, -1.14393284e-01,  2.25116493e-02,
#          -1.16923080e-02,  1.35463728e-02, -1.99069429e-01,
#           6.49081927e-02],
#         [ 1.57653305e-02,  3.26738028e-02,  7.02418482e-03,
#           3.40597874e-02, -5.54168349e-02, -2.94072348e-03,
#          -1.91644015e-02,  9.68662380e-03, -8.99205440e-02,
#           1.78968960e-02],
#         [ 9.56196568e-02,  2.29563528e-01, -2.94818584e-01,
#          -1.93311074e-01, -3.25616906e-01,  1.36402692e-01,
#           1.03772288e-02,  6.62631828e-02, -1.44709065e-01,
#          -1.65469241e-01]]])

# %%
ccm1 = ssm_proj1.autocorrelation(10, proj=V)
ccm2 = ssm_proj2.autocorrelation(10)

# %%
# VERY IMPORTANT: Verficiation of minimum phase property

# %%
np.abs(np.linalg.eigvals(A - BB @ np.linalg.inv(DD) @ V))
# Out:
# array([0.73777688, 0.57993333, 0.57993333, 0.40550238, 0.40550238,
#        0.26291958, 0.26291958, 0.38505546, 0.23669226, 0.0476823 ])

# %%
ccm2
# Out:
# array([[[20.49850374,  5.51089172],
#         [ 5.51089172, 29.34478341]],
#
#        [[-0.15218347, -2.24580294],
#         [-4.73528694, -8.63995405]],
#
#        [[-0.49370838, -0.13385936],
#         [ 0.70223348,  1.95747754]],
#
#        [[-0.9917214 , -1.85316767],
#         [ 1.37665605, -1.02461924]],
#
#        [[-0.93370732,  0.12956689],
#         [-0.36188606,  0.71043229]],
#
#        [[-0.37456093, -0.73041463],
#         [-0.84304363, -1.44923945]],
#
#        [[ 0.19934368,  0.21764652],
#         [-0.55198461, -0.27218266]],
#
#        [[ 0.26242531,  0.09202791],
#         [-0.41545162, -0.47392901]],
#
#        [[ 0.218259  ,  0.18392069],
#         [-0.14041895, -0.12721794]],
#
#        [[ 0.11686732,  0.05895613],
#         [ 0.03269685, -0.08536792]]])

# %%
ccm1
# Out:
# array([[[20.49850374,  5.51089172],
#         [ 5.51089172, 29.34478341]],
#
#        [[-0.15218347, -2.24580294],
#         [-4.73528694, -8.63995405]],
#
#        [[-0.49370838, -0.13385936],
#         [ 0.70223348,  1.95747754]],
#
#        [[-0.9917214 , -1.85316767],
#         [ 1.37665605, -1.02461924]],
#
#        [[-0.93370732,  0.12956689],
#         [-0.36188606,  0.71043229]],
#
#        [[-0.37456093, -0.73041463],
#         [-0.84304363, -1.44923945]],
#
#        [[ 0.19934368,  0.21764652],
#         [-0.55198461, -0.27218266]],
#
#        [[ 0.26242531,  0.09202791],
#         [-0.41545162, -0.47392901]],
#
#        [[ 0.218259  ,  0.18392069],
#         [-0.14041895, -0.12721794]],
#
#        [[ 0.11686732,  0.05895613],
#         [ 0.03269685, -0.08536792]]])

# %%
def solve_riccati(F, G, H, J):
    
    # Form matrix pencil
    A = np.block([[F - G @ np.linalg.inv(J + J.T) @ H, np.zeros((H.shape[1], H.shape[1]))],
                  [-H.T @ np.linalg.inv(J + J.T) @ H, np.eye(H.shape[1])]])

    B = np.block([[np.eye(G.shape[0]), -G @ np.linalg.inv(J + J.T) @ G.T], \
                  [np.zeros((G.shape[0], F.shape[0])), F.T - H.T @ np.linalg.inv(J + J.T) @ G.T]])
    
    # Need to compute the stable deflating subspace of the above matrix pencil

    # For now, use scipy's built in sorting function
    AA, BB, _, _, Q, Z = scipy.linalg.ordqz(A, B, output='complex', sort='iuc')
#     # Need to get the block diagonals to obtain the eigenvalues
#     AAblocks = [AA[2*i:2*i + 2,2*i:2*i + 2] for i in range(AA.shape[0]//2)]
#     BBblocks = [BB[2*i:2*i + 2,2*i:2*i + 2] for i in range(BB.shape[0]//2)]
        
    # Identify generalized eigenvalues with absolute value < 1
#     lam = np.divide(np.linalg.eigvals(AA), np.linalg.eigvals(BB))
#     stable_eigs = np.squeeze(np.argwhere(np.abs(lam) < 1))
    n = Z.shape[0]    
    Zstable = Z[:, 0:n//2]    
    
    return Zstable[n//2:, :] @ np.linalg.inv(Zstable[0:n//2, :])

# %% [markdown]
# ### Comparison of Balanced Bases to Optimized Subspaces - PI is lower by balancing!

# %%
from dca.dca import DynamicalComponentsAnalysis as DCA
from dca.cov_util import calc_cov_from_cross_cov_mats, calc_pi_from_cov
from neurosim.utils.riccati import riccati_solve

# %%
# Scale matrix non-normality
ssdim = 20

# B = np.random.normal(size=(10, 10))
B = np.eye(ssdim)
C = np.eye(ssdim)
#D = 1e-3 * np.eye(ssdim)

reps = 10
t = 15

# loadings_balanced = np.zeros((reps, 10))
# loadings_optimized = np.zeros((reps, 10))

pi_cc_top2 = np.zeros(reps)
pi_balanced_proj = np.zeros(reps)
pi_opt = np.zeros(reps)

for rep in tqdm(range(reps)):

    A = 1/5 * np.random.normal(size=(ssdim, ssdim))

    if max(np.abs(np.linalg.eigvals(A))) >= 1:
        while max(np.abs(np.linalg.eigvals(A))) >= 1:
            A = 1/5 * np.random.normal(size=(ssdim, ssdim))

    ssr = SSR(A=A, B=B, C=C)
    ssr.solve_min_phase()
    ssr.solve_max_phase()
    Pmin = riccati_solve(ssr.A, ssr.C, ssr.Cbar, ssr.cov, Pinit=ssr.P, tol=1e-8)
    Qmin = riccati_solve(ssr.A.T, ssr.Cbar, ssr.C, ssr.cov, Pinit=ssr.P, tol=1e-8)

    # Cholesky decomposition
    R = np.linalg.cholesky(Pmin)
    U, s, Vh = np.linalg.svd(R.T @ Qmin @ R)

    T = scipy.linalg.sqrtm(np.diag(np.sqrt(s))) @ U.T @ np.linalg.inv(R)

    # Quick check that we are getting the right PI
    assert(np.isclose(-1/2 * np.sum(np.log(1 - s)), ssr.pi(10), atol=1e-5))

    pi_cc_top2[rep] = -1 * np.sum(np.log(1-s[0:2]))

    # Optimize using the exact covariance sequence
    ssm = SSR(A=A, B=B, C=C)

    ccm1 = ssm.autocorrelation(t)
    ccm2 = ssm.autocorrelation(2 * t)

    dcamodel = DCA(d=2, T=t)
    dcamodel.cross_covs = ccm2
    dcamodel.fit_projection()
    
    pi_opt[rep] = max(dcamodel.scores)


    # Check against the projection suggested by balanced truncation
    Cbalanced = C @ np.linalg.inv(T)
    Cbalanced = C[0:2, :]

    ssm_balanced = SSR(A = A, B=B, C=Cbalanced)
    pi_balanced_proj[rep] = ssm_balanced.pi(10)
# Out:
# 100%|██████████| 10/10 [00:09<00:00,  1.07it/s]

# %%
pi_opt
# Out:
# array([2.52782579, 1.98992782, 1.55890989, 2.49144498, 3.05700805,
#        1.58311454, 2.86251124, 4.48079095, 2.58158331, 2.29356703])

# %%
pi_balanced_proj
# Out:
# array([0.8207508 , 0.39164305, 0.40566156, 1.41757604, 0.93335865,
#        0.34764095, 1.19588973, 2.72997262, 1.37273505, 0.72110266])
