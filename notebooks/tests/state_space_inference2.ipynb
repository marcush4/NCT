# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import sys
import scipy 
from scipy.stats import ortho_group
import pdb
import matplotlib.pyplot as plt
from glob import glob
import importlib

# %%
from statsmodels import tsa

# %%
sys.path.append('../..')

# %%
from neurosim.models.ssr import StateSpaceRealization as SSR
from subspaces import estimate_autocorrelation, SubspaceIdentification, IteratedStableEstimator

# %% [markdown]
# ### Model Order Identification

# %%
from tqdm import tqdm
from sklearn.model_selection import KFold
from pyuoi.linear_model.var import VAR, _form_var_problem

# %%
state_dim = 20
obs_dim = 10

model_reps = 10
trajectory_reps = 10

N = [int(5e2), int(1e3), int(5e3), int(1e4), int(5e4)]
# Test (1) How the different model selection criteria perform in MOE identification 
# (2) Whether forward vs. reverse time estimates give systematically better predictions
# (3) OLS vs. Ridge vs. IteratedStability in terms of fit to cross-correlation matrices

n_folds = 5

results = []

for i in tqdm(range(model_reps)):
    A = np.random.normal(scale=1/(1.7 * np.sqrt(state_dim)), size=(state_dim, state_dim))
    while max(np.abs(np.linalg.eigvals(A))) > 0.99:
        A = np.random.normal(scale=1/(1.7 * np.sqrt(state_dim)), size=(state_dim, state_dim))

    C = scipy.stats.ortho_group.rvs(state_dim)[:, 0:obs_dim].T
    ssr = SSR(A=A, B=np.eye(A.shape[0]), C=C)
    ccm0 = ssr.autocorrelation(5)
    for j, n in tqdm(enumerate(N)):
        for k in range(trajectory_reps):
            y = ssr.trajectory(n)
            fold_idx = 0
            for train_idxs, test_idxs in KFold(5).split(np.arange(y.shape[0])):
                ccm1 = estimate_autocorrelation(y[train_idxs], 5)
                ccm2 = estimate_autocorrelation(y[test_idxs], 5)

                result = {}
                result['fold_idx'] = fold_idx
                result['N'] = n
                result['trajectory_rep'] = k
                result['model_rep'] = i
                result['true_params'] = (A, C)
                result['autocorr_true'] = ccm0
                result['autocorr_train'] = ccm1
                result['autocorr_test'] = ccm2


                for var_order in [1, 2, 3]:
                    varmodel = VAR(order=var_order, estimator='ols')
                    varmodel.fit(y)
                    result['coef'] = varmodel.coef_

                for model_order in np.arange(15, 27, 2):
                    ssid = SubspaceIdentification(T=3, estimator=IteratedStableEstimator)

                    A, C, Cbar, L0, Q, R, S = ssid.identify(y[train_idxs], order=model_order)

                    result['coef'] = (A, C, Cbar, L0, Q, R, S)
                    results.append(result)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Rows of VAR matrix processed: 10it [00:00, 3271.43it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2415.38it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 1923.29it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2799.75it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2685.04it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2246.43it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3977.91it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2447.80it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2033.01it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3005.59it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2744.07it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2275.93it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3324.59it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2639.75it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2190.01it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3731.26it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2762.32it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2128.98it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3680.83it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3250.89it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2475.68it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3271.18it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2540.31it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 1466.03it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3807.47it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3185.95it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2458.56it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3508.12it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2661.02it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2253.43it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2993.58it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2949.58it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 1995.67it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3161.46it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2691.76it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2182.83it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2590.84it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2413.29it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2529.43it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3402.81it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3012.07it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2455.25it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3368.65it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2872.02it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2146.63it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3213.04it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2666.61it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2184.65it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3443.60it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3307.55it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2217.80it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3618.27it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2645.91it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2009.25it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3714.40it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2812.70it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2187.84it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3201.51it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2629.99it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2130.82it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3538.60it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2747.66it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2129.09it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3076.81it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2602.89it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 1995.96it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 3684.39it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2630.65it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2193.21it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2958.53it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2652.27it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2231.13it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2925.92it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2587.00it/s]
#
# Rows of VAR matrix processed: 10it [00:00, 2085.37it/s]
# 0it [00:09, ?it/s]
#   0%|          | 0/10 [00:09<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24191/23296854.py in <module>
#      48                 for model_order in np.arange(15, 27, 2):
#      49                     ssid = SubspaceIdentification(T=3, estimator=IteratedStableEstimator)
# ---> 50                     A, C, Cbar, L0, Q, R, S = ssid.identify(y[train_idxs], order=model_order)
#      51
#      52                     result['coef'] = (A, C, Cbar, L0, Q, R, S)
#
# ~/nse/neural_control/subspaces.py in identify(self, y, order, ccm, hankel_toeplitz, T)
#     457         zt, zt1, zbart, zbart1 = self.get_predictor_space(y, hankel_toeplitz, T, int(order))
#     458         # Identify (forward time)
# --> 459         A, C, Cbar, rho_A, rho_C = self.estimator.fit(y[self.T-1:-1, :], zt, zt1, return_residuals=True)
#     460
#     461         # Need to correct positive realness
#
# ~/nse/neural_control/subspaces.py in fit(self, y, Xt, Xt1, return_residuals)
#     425
#     426         if not check_stability(A):
# --> 427             A = self.solve_qp(A, Xt, Xt1)
#     428
#     429         if return_residuals:
#
# ~/nse/neural_control/subspaces.py in solve_qp(self, A, x0, x1)
#     387
#     388         # Solve QP
# --> 389         a = quadprog.solve_qp(P, q, G, h, 0)[0]
#     390
#     391         A0 = A
#
# quadprog/quadprog.pyx in quadprog.solve_qp()
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#      21
#      22
# ---> 23 @set_array_function_like_doc
#      24 @set_module('numpy')
#      25 def asarray(a, dtype=None, order=None, *, like=None):
#
# KeyboardInterrupt:

# %%
from em import StableStateSpaceML
from statsmodels.tsa.statespace.varmax import VARMAX
import time

# %%
state_dim = 20
obs_dim = 10

model_reps = 1
trajectory_reps = 10

N = [int int(5e3)]
# Test (1) How the different model selection criteria perform in MOE identification 
# (2) Whether forward vs. reverse time estimates give systematically better predictions
# (3) OLS vs. Ridge vs. IteratedStability in terms of fit to cross-correlation matrices

n_folds = 5

results = []

for i in tqdm(range(model_reps)):
    A = np.random.normal(scale=1/(1.7 * np.sqrt(state_dim)), size=(state_dim, state_dim))
    while max(np.abs(np.linalg.eigvals(A))) > 0.99:
        A = np.random.normal(scale=1/(1.7 * np.sqrt(state_dim)), size=(state_dim, state_dim))

    C = scipy.stats.ortho_group.rvs(state_dim)[:, 0:obs_dim].T
    ssr = SSR(A=A, B=np.eye(A.shape[0]), C=C)
    ccm0 = ssr.autocorrelation(5)
    for j, n in tqdm(enumerate(N)):
        for k in range(trajectory_reps):
            y = ssr.trajectory(n)
            fold_idx = 0
            for train_idxs, test_idxs in KFold(5).split(np.arange(y.shape[0])):
                ccm1 = estimate_autocorrelation(y[train_idxs], 5)
                ccm2 = estimate_autocorrelation(y[test_idxs], 5)

                result = {}
                result['fold_idx'] = fold_idx
                result['N'] = n
                result['trajectory_rep'] = k
                result['model_rep'] = i
                result['true_params'] = (A, C)
                result['autocorr_true'] = ccm0
                result['autocorr_train'] = ccm1
                result['autocorr_test'] = ccm2

                for model_order in range(5, 10):
                    result['order'] = model_order
                    try:   
                        t0 = time.time()                 
                        ssm = StableStateSpaceML(max_iter=50)
                        ssm.fit(y[train_idxs], state_dim=model_order)
                        result['coef'] = (ssm.A, ssm.C, ssm.R, ssm.x0, ssm.Sigma0)
                        print(time.time() - t0)
                    except:
                        result['coef'] = 'Fitting failed'
                    results.append(result)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# E step: 1.354347
# M step: 0.147017
# E step: 1.374358
# M step: 0.141715
# E step: 1.329966
# M step: 0.105737
# E step: 1.337321
# M step: 0.107113
# E step: 1.340536
# M step: 0.099195
# E step: 1.358083
# M step: 0.098696
# E step: 1.358243
# M step: 0.145554
# E step: 1.392288
# M step: 0.103665
# E step: 1.369696
# M step: 0.098907
# E step: 1.372622
# M step: 0.107252
# E step: 1.378311
# M step: 0.132406
# E step: 1.300604
# M step: 0.148490
# E step: 1.374848
# M step: 0.105130
# E step: 1.351195
# M step: 0.126753
# E step: 1.347877
# M step: 0.105191
# E step: 1.423412
# M step: 0.100155

# %%
state_dim = 20
obs_dim = 10

model_reps = 10
trajectory_reps = 10

N = [int(5e2), int(1e3), int(5e3), int(1e4), int(5e4)]
# Test (1) How the different model selection criteria perform in MOE identification 
# (2) Whether forward vs. reverse time estimates give systematically better predictions
# (3) OLS vs. Ridge vs. IteratedStability in terms of fit to cross-correlation matrices

n_folds = 5

results_varma = []

for i in tqdm(range(model_reps)):
    A = np.random.normal(scale=1/(1.7 * np.sqrt(state_dim)), size=(state_dim, state_dim))
    while max(np.abs(np.linalg.eigvals(A))) > 0.99:
        A = np.random.normal(scale=1/(1.7 * np.sqrt(state_dim)), size=(state_dim, state_dim))

    C = scipy.stats.ortho_group.rvs(state_dim)[:, 0:obs_dim].T
    ssr = SSR(A=A, B=np.eye(A.shape[0]), C=C)
    ccm0 = ssr.autocorrelation(5)
    for j, n in tqdm(enumerate(N)):
        for k in range(trajectory_reps):
            y = ssr.trajectory(n)
            fold_idx = 0
            for train_idxs, test_idxs in KFold(5).split(np.arange(y.shape[0])):
                ccm1 = estimate_autocorrelation(y[train_idxs], 5)
                ccm2 = estimate_autocorrelation(y[test_idxs], 5)

                result = {}
                result['fold_idx'] = fold_idx
                result['N'] = n
                result['trajectory_rep'] = k
                result['model_rep'] = i
                result['true_params'] = (A, C)
                result['autocorr_true'] = ccm0
                result['autocorr_train'] = ccm1
                result['autocorr_test'] = ccm2

                for order_tup in [(1, 1), (1, 2), (2, 1), (2, 2)]:
                    result['order'] = order_tup

                    try:
                        varmamodel = VARMAX(endog=y[train_idxs], order=order_tup).fit(maxiter=50)
                        result['coef'] = (varmamodel.coefficient_matrices_var, varmamodel.coefficient_matrices_vma)
                    except:
                        result['coef'] = 'Fit failed'                
                    results_varma.append(result)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/home/akumar/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/tsa/statespace/varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          265     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.50258D+01    |proj g|=  1.01948D-01
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#   265      2      4      1     0     0   5.162D-02   1.497D+01
#   F =   14.967203114235780
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /home/akumar/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /home/akumar/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/tsa/statespace/varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          365     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.47839D+01    |proj g|=  1.45992D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#   365      2      4      1     0     0   4.043D-02   1.472D+01
#   F =   14.715014917451599
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /home/akumar/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /home/akumar/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/tsa/statespace/varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          365     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.47251D+01    |proj g|=  5.96925D-02
# 0it [00:14, ?it/s]
#   0%|          | 0/10 [00:14<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16070/2160279100.py in <module>
#      41
#      42                 for order_tup in [(1, 1), (1, 2), (2, 1), (2, 2)]:
# ---> 43                     varmamodel = VARMAX(endog=y[train_idxs], order=order_tup).fit(maxiter=2)
#      44                     result['order'] = order_tup
#      45                     result['coef'] = (varmamodel.coefficient_matrices_var, varmamodel.coefficient_matrices_vma)
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     707                                                full_output=full_output,
#     708                                                disp=disp, callback=callback,
# --> 709                                                skip_hessian=True, **kwargs)
#     710
#     711         # Just return the fitted parameters if requested
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     569                                                        callback=callback,
#     570                                                        retall=retall,
# --> 571                                                        full_output=full_output)
#     572         # Restore cov_type, cov_kwds and use_t
#     573         optim_settings.update(kwds)
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     242                              disp=disp, maxiter=maxiter, callback=callback,
#     243                              retall=retall, full_output=full_output,
# --> 244                              hess=hessian)
#     245
#     246         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     652                                      callback=callback, args=fargs,
#     653                                      bounds=bounds, disp=disp,
# --> 654                                      **extra_kwargs)
#     655
#     656     if full_output:
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     196
#     197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 198                            **opts)
#     199     d = {'grad': res['jac'],
#     200          'task': res['message'],
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     266             self._update_x_impl(x)
#     267         self._update_fun()
# --> 268         self._update_grad()
#     269         return self.f, self.g
#     270
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     236     def _update_grad(self):
#     237         if not self.g_updated:
# --> 238             self._update_grad_impl()
#     239             self.g_updated = True
#     240
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     154                 self.ngev += 1
#     155                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
# --> 156                                            **finite_diff_options)
#     157
#     158         self._update_grad_impl = update_grad
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     485         if sparsity is None:
#     486             return _dense_difference(fun_wrapped, x0, f0, h,
# --> 487                                      use_one_sided, method)
#     488         else:
#     489             if not issparse(sparsity) and len(sparsity) == 2:
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/base/model.py in f(params, *args)
#     529
#     530         def f(params, *args):
# --> 531             return -self.loglike(params, *args) / nobs
#     532
#     533         if method == 'newton':
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     937             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     938
# --> 939         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     940
#     941         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     981         kwargs.setdefault('conserve_memory',
#     982                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983         kfilter = self._filter(**kwargs)
#     984         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                         self.loglikelihood_burn)
#
# ~/anaconda3/envs/dyn/lib/python3.7/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     904
#     905         # Run the filter
# --> 906         kfilter()
#     907
#     908         return kfilter
#
# KeyboardInterrupt:
